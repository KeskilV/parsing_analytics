# %%
#13-10-2022 создана tests 
#12-10-2022 http://localhost:8909/edit/work/parsing/Parsing_NKO/results/SL_%D0%B2%D1%81%D0%B5%D0%AE%D0%982022-09-01-15-28/_joined-2022-09-09-10-18.xlsx
#22-09-2022 alrosa
#07-09-2022 
#06-09-2022 parcing
#05-09-2022 dct -> dict, optim
#04-09-2022 
#02-09-2022 разработка классов
#01-09-2022 PHC 8000 import importlib 
#25-08-2022 Создна копия для SUNLIGHT
#25-08-2022 Для цек БК и ПДК
#07-07-2022 0 обработка нефти 
#06-07-2022 серебро https://miuz.ru/catalog/filter/offers_metall-is-serebro/page=2/
#16-06-2022 Для Алексея Руб-Из-Сап
#24-05-2022 Запуск парсинга result is 'mius240522_0-4154.xlsx'

# %% [markdown]
# # imports

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # load data

# %%
! jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
! dir
# Out:
#  Том в устройстве C имеет метку Acer
#  Серийный номер тома: 0682-E256
#
#  Содержимое папки C:\Users\diva0\work\parsing\Parsing_NKO
#
# 12.10.2022  05:26    <DIR>          .
# 12.10.2022  05:26    <DIR>          ..
# 24.04.2022  07:11            10 244 .DS_Store
# 20.04.2022  02:08    <DIR>          .idea
# 12.10.2022  05:16    <DIR>          .ipynb_checkpoints
# 20.04.2022  02:08         1 055 938 AnaliticRep031221.ipynb
# 04.07.2022  15:22         1 102 564 AnaliticRep060622EPL_Кольца_с_брилл-62.ipynb
# 20.04.2022  02:08         1 214 609 AnaliticRep061221-KDM1C8.ipynb
# 06.05.2022  16:58         1 344 650 AnaliticRep140422MUIZ_Кольца_с_брилл.ipynb
# 05.05.2022  13:56         1 075 657 AnaliticRep220422EGELGE_брилл.ipynb
# 04.07.2022  15:22         1 719 617 AnaliticRep240522MUIZ_Кольца_с_брилл.ipynb
# 07.10.2022  00:33           907 503 collectxls_reps.ipynb
# 07.10.2022  00:33             5 526 data.xlsx
# 24.04.2022  07:11           261 216 Egelge_1after_parsing.ipynb
# 20.04.2022  02:08    <DIR>          env
# 04.07.2022  15:22           582 579 for_parsing_func.ipynb
# 04.07.2022  15:22    <DIR>          jewels
# 07.10.2022  00:33    <DIR>          links
# 07.10.2022  00:33    <DIR>          modules
# 20.04.2022  02:08         1 256 682 MUIZ_justcode.ipynb
# 12.10.2022  05:26           201 051 oil_quality_improve.ipynb
# 20.04.2022  02:08           851 329 Parsing.html
# 07.10.2022  00:33         2 331 956 ParsingEgelge.ipynb
# 07.10.2022  00:33         1 171 612 ParsingEPL.ipynb
# 04.07.2022  15:22           960 503 ParsingKierge.ipynb
# 07.10.2022  00:33           975 470 ParsingMiuz.ipynb
# 20.04.2022  02:08           225 819 ParsingNKObyAita.ipynb
# 07.10.2022  00:33         2 365 576 ParsingRNIMU.ipynb
# 07.10.2022  00:33           157 938 ParsingSUNLIGHT.ipynb
# 07.10.2022  00:33           603 300 pars_16-06-2022_muiz_RSE.xlsx
# 12.10.2022  05:11               597 README.md
# 20.04.2022  02:08             3 308 requiremnts.txt
# 07.10.2022  00:33    <DIR>          results
# 04.07.2022  15:22           208 780 resultslinks4154_2410522.xlsx
# 24.04.2022  07:11    <DIR>          rusprice
# 07.10.2022  00:33    <DIR>          tasklogs
# 04.07.2022  15:22             7 296 temp10.xlsx
# 20.04.2022  02:08               876 Untitled.ipynb
# 20.04.2022  02:08           482 465 Untitled1-Copy1.ipynb
# 24.04.2022  07:11           614 288 Untitled1.ipynb
# 20.04.2022  02:08           342 594 visio_matplotlib.ipynb
# 07.10.2022  00:33    <DIR>          __pycache__
# 07.10.2022  00:33    <DIR>          Парсинг МЮЗ Эгэлгэ ЭПЛ Sunlight
# 04.07.2022  15:22           360 018 Разница в стомости изделия Красноярск Москва МЮЗ.docx
#               31 файлов     22 401 561 байт
#               13 папок  323 803 885 568 байт свободно

# %%
df = pd.read_excel('results/SL_всеЮИ2022-09-01-15-28/_joined-2022-09-09-10-18.xlsx')

# %%
len(df)
# Out:
# 35655

# %%
df.drop(columns=['Unnamed: 0',	'Unnamed: 0.1'], inplace=True)

# %%
df.head()
# Out:
#                                             h1              art   price  \
# 0                   Золотое кольцо с фианитами   Артикул: 68001   6294₽
# 1  Золотой браслет с изумрудами и бриллиантами  Артикул: 109122  35994₽
# 2                            Серебряное кольцо  Артикул: 289895    894₽
# 3                 Серебряные серьги с топазами  Артикул: 316910   1914₽
# 4                Серебряное кольцо с аметистом  Артикул: 290202   3594₽
#
#     price2                                               gold  gold2  weight  \
# 0   20980₽  Артикул: 68001;Кольцо, вставка:  фианит;    \n...    NaN     NaN
# 1  119980₽  Артикул: 109122;Браслет с 12 бриллиантами, огр...    NaN     NaN
# 2    2980₽  Артикул: 289895;Кольцо    \nСеребро 925 пробы....    NaN     NaN
# 3    6380₽  Артикул: 316910;Серьги, вставка:  топаз;   \nС...    NaN     NaN
# 4   11980₽  Артикул: 290202;Кольцо, вставка:  аметист;    ...    NaN     NaN
#
#    gems  gems2                                                url  \
# 0   NaN    NaN       https://sunlight.net/catalog/ring_68001.html
# 1   NaN    NaN  https://sunlight.net/catalog/bracelets_109122....
# 2   NaN    NaN      https://sunlight.net/catalog/ring_289895.html
# 3   NaN    NaN   https://sunlight.net/catalog/earring_316910.html
# 4   NaN    NaN      https://sunlight.net/catalog/ring_290202.html
#
#                                                   d1  \
# 0                  7185Б*&Белое золото&Фианит&1.04 г
# 1  70514-B5R-02&Розовое золото&Бриллиант; Изумруд...
# 2                   410-10-471&РОССИЯ&Серебро&3.89 г
# 3         1220015147-501&РОССИЯ&Серебро&Топаз&2.94 г
# 4                  1405931729&Серебро&Аметист&5.66 г
#
#                                                d0  \
# 0         SERGEY GRIBNYAKOV&Белое и желтое золото
# 1              SERGEY GRIBNYAKOV&Золото. Изумруды
# 2  SERGEY GRIBNYAKOV&Гладкие серебряные украшения
# 3                      SERGEY GRIBNYAKOV&NATURIKA
# 4                                  Balex&NATURIKA
#
#                               source                                  filname
# 0  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 1  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 2  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 3  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 4  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv

# %%
len(df)
# Out:
# 35647

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35647 entries, 0 to 35654
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   h1       35647 non-null  object
#  1   art      35647 non-null  object
#  2   price    35647 non-null  object
#  3   price2   35502 non-null  object
#  4   gold     35647 non-null  object
#  5   gold2    0 non-null      float64
#  6   weight   0 non-null      float64
#  7   gems     0 non-null      float64
#  8   gems2    0 non-null      float64
#  9   url      35647 non-null  object
#  10  d1       35647 non-null  object
#  11  d0       35598 non-null  object
#  12  source   35647 non-null  object
#  13  filname  35647 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 4.1+ MB

# %% [markdown]
# # data processing

# %% [markdown]
# ## Разработка rе

# %% [markdown]
# ### art (артикул)

# %%
pd.options.display.max_colwidth = 200

# %%
len(df)
# Out:
# 35647

# %%
len(df.loc[:,'gold'].apply(lambda x: x.split(';')[0][8]).unique())
# Out:
# 1

# %%
df['art'] = df.loc[:,'gold'].apply(lambda x: x.split(';')[0][8:])

# %%
df.head()
# Out:
#                                             h1      art   price   price2  \
# 0                   Золотое кольцо с фианитами    68001   6294₽   20980₽
# 1  Золотой браслет с изумрудами и бриллиантами   109122  35994₽  119980₽
# 2                            Серебряное кольцо   289895    894₽    2980₽
# 3                 Серебряные серьги с топазами   316910   1914₽    6380₽
# 4                Серебряное кольцо с аметистом   290202   3594₽   11980₽
#
#                                                                                                                                                                                                       gold  \
# 0                                                                                  Артикул: 68001;Кольцо, вставка:  фианит;    \n 585 пробы.;Вес изделия: 1.04г;Кольцо, вставка:  фианит;    \n 585 пробы.
# 1  Артикул: 109122;Браслет с 12 бриллиантами, огранка круг 17 граней, 0.04 карат, цвет 2, чистота 2, тип огранки Б;\n1 изумрудом, 0.08 карат, цвет 3, чистота 3, тип огранки В;    \nРозовое золото 585...
# 2                                                                                                         Артикул: 289895;Кольцо    \nСеребро 925 пробы.;Вес изделия: 3.89г;Кольцо    \nСеребро 925 пробы.
# 3                                                                       Артикул: 316910;Серьги, вставка:  топаз;   \nСеребро 925 пробы.;Вес изделия: 2.94г;Серьги, вставка:  топаз;   \nСеребро 925 пробы.
# 4                                                                 Артикул: 290202;Кольцо, вставка:  аметист;    \nСеребро 925 пробы.;Вес изделия: 5.66г;Кольцо, вставка:  аметист;    \nСеребро 925 пробы.
#
#    gold2  weight  gems  gems2  \
# 0    NaN     NaN   NaN    NaN
# 1    NaN     NaN   NaN    NaN
# 2    NaN     NaN   NaN    NaN
# 3    NaN     NaN   NaN    NaN
# 4    NaN     NaN   NaN    NaN
#
#                                                   url  \
# 0        https://sunlight.net/catalog/ring_68001.html
# 1  https://sunlight.net/catalog/bracelets_109122.html
# 2       https://sunlight.net/catalog/ring_289895.html
# 3    https://sunlight.net/catalog/earring_316910.html
# 4       https://sunlight.net/catalog/ring_290202.html
#
#                                                       d1  \
# 0                      7185Б*&Белое золото&Фианит&1.04 г
# 1  70514-B5R-02&Розовое золото&Бриллиант; Изумруд&6.02 г
# 2                       410-10-471&РОССИЯ&Серебро&3.89 г
# 3             1220015147-501&РОССИЯ&Серебро&Топаз&2.94 г
# 4                      1405931729&Серебро&Аметист&5.66 г
#
#                                                d0  \
# 0         SERGEY GRIBNYAKOV&Белое и желтое золото
# 1              SERGEY GRIBNYAKOV&Золото. Изумруды
# 2  SERGEY GRIBNYAKOV&Гладкие серебряные украшения
# 3                      SERGEY GRIBNYAKOV&NATURIKA
# 4                                  Balex&NATURIKA
#
#                               source                                  filname
# 0  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 1  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 2  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 3  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv
# 4  results/SL_всеЮИ2022-09-01-15-28/  SL_всеЮИ2022-09-01-16-15-1251-12952.csv

# %% [markdown]
# ### vidizd (вид изделия)

# %%
t = df.loc[:100,'gold'].apply(lambda x: x.split(';')[1])[99]
t
# Out:
# 'Серьги с 130 бриллиантами, огранка круг 17 граней, 0.27 карат, цвет 2, чистота 3, тип огранки Б'

# %%
#pattern_vidizd = r"[\D]+" 
pattern_vidizd = r"[а-яА-ЯёЁ]+"

# %%
re.match(pattern_vidizd,t)[0]
# Out:
# 'Серьги'

# %%
re.search(pattern_vidizd,t)[0]
# Out:
# 'Серьги'

# %%
re.findall(pattern_vidizd,t)#[0]
# Out:
# ['Серьги',
#  'с',
#  'бриллиантами',
#  'огранка',
#  'круг',
#  'граней',
#  'карат',
#  'цвет',
#  'чистота',
#  'тип',
#  'огранки',
#  'Б']

# %%
df ['vidizd0'] = df.loc[:,'gold'].apply(
    lambda x: re.search(pattern_vidizd,x.split(
        ';')[1])[0] if re.search(
        pattern_vidizd,x.split(';')[1]) else x)

# %%
#если не пусто - надо подумать потом что с ними делать
df[df ['vidizd0'].isna()]
# Out:
#                                h1     art  price  price2  \
# 11319  Золотое обручальное кольцо   89525  7090₽  23633₽
#
#                                       gold  gold2  weight  gems  gems2  \
# 11319  Артикул: 89525; ;Вес изделия: 1.97г    NaN     NaN   NaN    NaN
#
#                                                 url  \
# 11319  https://sunlight.net/catalog/ring_89525.html
#
#                                         d1  \
# 11319  628-4*&Розовое золото&4,0 мм&1.97 г
#
#                                          d0  \
# 11319  SERGEY GRIBNYAKOV&Обручальные кольца
#
#                                   source  \
# 11319  results/SL_всеЮИ2022-09-01-15-28/
#
#                                        filname vidizd0
# 11319  SL_всеЮИ2022-09-01-16-15-1251-12952.csv    None

# %%
df['vidizd0'].value_counts()
# Out:
# Серьги                                 13748
# Кольцо                                 10673
# Подвеска                                4580
# Браслет                                 2145
# Шейное                                  2129
# Цепь                                     742
# Брошь                                    564
# Колье                                    327
# Пирсинг                                  223
# Серьга                                   170
# Пусеты                                    86
# Запонки                                   56
# Ножной                                    50
# вставка                                   47
# Кулон                                     32
# Зажим                                     18
# Значок                                    11
# Брелок                                     6
# Мощевик                                    6
# Ожерелье                                   5
# Икона                                      5
# с                                          5
# Цепочка                                    4
# СерьгиФианит                               4
# Серебро                                    3
# КольцоФианит                               2
# ПодвескаФианит                             2
# Артикул: 89525; ;Вес изделия: 1.97г        1
# Медальон                                   1
# Серебряная                                 1
# Слейв                                      1
# Name: vidizd0, dtype: int64

# %%
df[df['vidizd0'] == 'Ножной']#изучаем хвост и шейное
 #'Ножной': 'Ножной браслет',
 #'Шейное'
# Out:
#                                           h1      art   price  price2  \
# 407              Золотой браслет с фианитами   233663   8560₽  28533₽
# 815    Серебряный ножной браслет с фианитами   329108   1314₽   4380₽
# 1629               Серебряный ножной браслет   325817    894₽   2980₽
# 2275                  Золотой ножной браслет   277842   4740₽  15800₽
# 2931        Золотой ножной браслет с ониксом   277833   6230₽  20767₽
# 3258                  Золотой ножной браслет   277848   6830₽  22767₽
# 3562                  Золотой ножной браслет   277846   5710₽  19033₽
# 4757                  Золотой ножной браслет   277850   5220₽  17400₽
# 5278                  Золотой ножной браслет   277859   7020₽  23400₽
# 5284                  Золотой ножной браслет   277856   7180₽  23933₽
# 5424        Золотой ножной браслет с ониксом   277853   6640₽  22133₽
# 5794               Серебряный ножной браслет   272248    834₽   2780₽
# 6978                  Золотой ножной браслет   331646   8280₽  27600₽
# 8686                      Серебряный браслет   264660   1614₽   5380₽
# 9038                  Золотой ножной браслет   277854   5600₽  18667₽
# 9495                  Золотой ножной браслет   277845   5700₽  19000₽
# 11042                 Золотой ножной браслет   277847   5540₽  18467₽
# 12747             Серебряный браслет на ногу   272250   2490₽   4980₽
# 13407                 Золотой ножной браслет   277858   6520₽  21733₽
# 14896             Серебряный браслет на ногу   268273    890₽   4450₽
# 14973     Золотой ножной браслет с фианитами   277861   4760₽  15867₽
# 15085              Серебряный ножной браслет   264328   3190₽  10633₽
# 15323              Серебряный ножной браслет   272243    894₽   2980₽
# 15789   Серебряный ножной браслет с жемчугом   329110   1914₽   6380₽
# 15901     Золотой ножной браслет с фианитами   277835   6350₽  21167₽
# 16029             Серебряный браслет на ногу   264320   2390₽   4780₽
# 18152                 Золотой ножной браслет   318258   6894₽  22980₽
# 18185             Серебряный браслет на ногу   264635    714₽   2380₽
# 19226                 Золотой ножной браслет   277840   5760₽  19200₽
# 19763                 Золотой ножной браслет   277852   5760₽  19200₽
# 20051              Серебряный ножной браслет   272244   1790₽   5967₽
# 21212     Золотой ножной браслет с фианитами   277841   4640₽  15467₽
# 21660             Серебряный браслет на ногу   269007    990₽   3300₽
# 22364  Серебряный ножной браслет с фианитами   329109   1194₽   3980₽
# 24393     Золотой ножной браслет с фианитами   277851   6490₽  21633₽
# 25596                 Золотой ножной браслет   277843   7320₽  24400₽
# 27052                 Золотой ножной браслет   277838   6330₽  21100₽
Ножной браслет    \nЖелтое золото 585 пробы.;Вес изделия: 1.01г;Ножной браслет    \nЖелтое золото 585 пробы.
# 30743  Артикул: 277836;Ножной браслет с 4 ониксами синтетическими, 0.32 карат;    \nЖелтое золото 585 пробы.;Вес изделия: 1.34г;Ножной браслет с 4 ониксами синтетическими, 0.32 карат;    \nЖелтое золото ...
# 31640  Артикул: 277834;Ножной браслет с 3 ониксами синтетическими, 0.24 карат;    \nРозовое золото 585 пробы.;Вес изделия: 1.28г;Ножной браслет с 3 ониксами синтетическими, 0.24 карат;    \nРозовое золот...
# 32074                                                                             Артикул: 233665;Ножной браслет    \nЖелтое золото 585 пробы.;Вес изделия: 1.55г;Ножной браслет    \nЖелтое золото 585 пробы.
# 33671                                                                              Артикул: 277857;Ножной браслет    \nЖелтое золото 585 пробы.;Вес изделия: 1.0г;Ножной браслет    \nЖелтое золото 585 пробы.
# 33967                                                                           Артикул: 277831;Ножной браслет    \nРозовое золото 585 пробы.;Вес изделия: 1.03г;Ножной браслет    \nРозовое золото 585 пробы.
# 34151                                                                                         Артикул: 264318;Ножной браслет    \nСеребро 925 пробы.;Вес изделия: 1.65г;Ножной браслет    \nСеребро 925 пробы.
# 34716  Артикул: 272242;Ножной браслет, вставка:  фианит;    \nСеребро 925 пробы.\n\nБыть в тренде – легко! Самые актуальные Украшения из коллекции SILVER FASHION: одно или сразу несколько – решать только...
# 34927                                                                                         Артикул: 264330;Ножной браслет    \nСеребро 925 пробы.;Вес изделия: 3.62г;Ножной браслет    \nСеребро 925 пробы.
# 35572                                                                           Артикул: 277839;Ножной браслет    \nРозовое золото 585 пробы.;Вес изделия: 1.11г;Ножной браслет    \nРозовое золото 585 пробы.
#
#        gold2  weight  gems  gems2  \
# 407      NaN     NaN   NaN    NaN
# 815      NaN     NaN   NaN    NaN
# 1629     NaN     NaN   NaN    NaN
# 2275     NaN     NaN   NaN    NaN
# 2931     NaN     NaN   NaN    NaN
# 3258     NaN     NaN   NaN    NaN
# 3562     NaN     NaN   NaN    NaN
# 4757     NaN     NaN   NaN    NaN
# 5278     NaN     NaN   NaN    NaN
# 5284     NaN     NaN   NaN    NaN
# 5424     NaN     NaN   NaN    NaN
# 5794     NaN     NaN   NaN    NaN
# 6978     NaN     NaN   NaN    NaN
# 8686     NaN     NaN   NaN    NaN
# 9038     NaN     NaN   NaN    NaN
# 9495     NaN     NaN   NaN    NaN
# 11042    NaN     NaN   NaN    NaN
# 12747    NaN     NaN   NaN    NaN
# 13407    NaN     NaN   NaN    NaN
# 14896    NaN     NaN   NaN    NaN
# 14973    NaN     NaN   NaN    NaN
# 15085    NaN     NaN   NaN    NaN
# 15323    NaN     NaN   NaN    NaN
# 15789    NaN     NaN   NaN    NaN
# 15901    NaN     NaN   NaN    NaN
# 16029    NaN     NaN   NaN    NaN
# 18152    NaN     NaN   NaN    NaN
# 18185    NaN     NaN   NaN    NaN
# 19226    NaN     NaN   NaN    NaN
# 19763    NaN     NaN   NaN    NaN
# 20051    NaN     NaN   NaN    NaN
# 21212    NaN     NaN   NaN    NaN
# 21660    NaN     NaN   NaN    NaN
# 22364    NaN     NaN   NaN    NaN
# 24393    NaN     NaN   NaN    NaN
# 25596    NaN     NaN   NaN    NaN
# 27052    NaN     NaN   NaN    NaN
# 34716                            S55078-A9W-01&Серебро&1.84 г
# 34927                            S16312-A9W-01&Серебро&3.62 г
# 35572                      12655-A5R-01&Розовое золото&1.11 г
#
#                                                     d0  \
# 407                                  JASMİNE JEWELLERY
# 815                SERGEY GRIBNYAKOV&СЕРЕБРО. Классика
# 1629    SERGEY GRIBNYAKOV&Гладкие серебряные украшения
# 2275                                 JASMİNE JEWELLERY
# 2931                                 JASMİNE JEWELLERY
# 3258                                 JASMİNE JEWELLERY
# 3562                                 JASMİNE JEWELLERY
# 4757                                 JASMİNE JEWELLERY
# 5278                                 JASMİNE JEWELLERY
# 5284                                 JASMİNE JEWELLERY
# 5424                                 JASMİNE JEWELLERY
# 5794               SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 6978   SERGEY GRIBNYAKOV&Золотые украшения без вставок
# 8686                           CamyG&Co&Серебро Италии
# 9038                                 JASMİNE JEWELLERY
# 9495                                 JASMİNE JEWELLERY
# 11042                                JASMİNE JEWELLERY
# 12747              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 13407                                JASMİNE JEWELLERY
# 14896              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 14973                                JASMİNE JEWELLERY
# 15085              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 15323              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 15789                SERGEY GRIBNYAKOV&БАРОЧНЫЙ ЖЕМЧУГ
# 15901                                JASMİNE JEWELLERY
# 16029              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 18152  SERGEY GRIBNYAKOV&Золотые украшения без вставок
# 18185              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 19226                                JASMİNE JEWELLERY
# 19763                                JASMİNE JEWELLERY
# 20051              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 21212                                JASMİNE JEWELLERY
# 21660              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 22364              SERGEY GRIBNYAKOV&СЕРЕБРО. Классика
# 24393                                JASMİNE JEWELLERY
# 25596                                JASMİNE JEWELLERY
# 27052                                JASMİNE JEWELLERY
# 27971                          CamyG&Co&Серебро Италии
# 28587                                JASMİNE JEWELLERY
# 29494                                JASMİNE JEWELLERY
# 30710                                JASMİNE JEWELLERY
# 30743                                JASMİNE JEWELLERY
# 31640                                JASMİNE JEWELLERY
# 32074                                JASMİNE JEWELLERY
# 33671                                JASMİNE JEWELLERY
# 33967                                JASMİNE JEWELLERY
# 34151              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 34716              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 34927              SERGEY GRIBNYAKOV&СЕРЕБРО. FASHION
# 35572                                JASMİNE JEWELLERY
#
#                                   source  \
# 407    results/SL_всеЮИ2022-09-01-15-28/
# 815    results/SL_всеЮИ2022-09-01-15-28/
# 1629   results/SL_всеЮИ2022-09-01-15-28/
# 2275   results/SL_всеЮИ2022-09-01-15-28/
# 2931   results/SL_всеЮИ2022-09-01-15-28/
# 3258   results/SL_всеЮИ2022-09-01-15-28/
# 3562   results/SL_всеЮИ2022-09-01-15-28/
# 4757   results/SL_всеЮИ2022-09-01-15-28/
# 5278   results/SL_всеЮИ2022-09-01-15-28/
# 5284   results/SL_всеЮИ2022-09-01-15-28/
# 5424   results/SL_всеЮИ2022-09-01-15-28/
# 5794   results/SL_всеЮИ2022-09-01-15-28/
# 6978   results/SL_всеЮИ2022-09-01-15-28/
# 8686   results/SL_всеЮИ2022-09-01-15-28/
# 9038   results/SL_всеЮИ2022-09-01-15-28/
# 9495   results/SL_всеЮИ2022-09-01-15-28/
# 11042  results/SL_всеЮИ2022-09-01-15-28/
# 12747  results/SL_всеЮИ2022-09-01-15-28/
# 13407  results/SL_всеЮИ2022-09-01-15-28/
# 14896  results/SL_всеЮИ2022-09-01-15-28/
# 14973  results/SL_всеЮИ2022-09-01-15-28/
# 15085  results/SL_всеЮИ2022-09-01-15-28/
# 15323  results/SL_всеЮИ2022-09-01-15-28/
# 15789  results/SL_всеЮИ2022-09-01-15-28/
# 15901  results/SL_всеЮИ2022-09-01-15-28/
# 16029  results/SL_всеЮИ2022-09-01-15-28/
# 18152  results/SL_всеЮИ2022-09-01-15-28/
# 18185  results/SL_всеЮИ2022-09-01-15-28/
# 19226  results/SL_всеЮИ2022-09-01-15-28/
# 19763  results/SL_всеЮИ2022-09-01-15-28/
# 20051  results/SL_всеЮИ2022-09-01-15-28/
# 21212  results/SL_всеЮИ2022-09-01-15-28/
# 21660  results/SL_всеЮИ2022-09-01-15-28/
# 22364  results/SL_всеЮИ2022-09-01-15-28/
# 24393  results/SL_всеЮИ2022-09-01-15-28/
# 25596  results/SL_всеЮИ2022-09-01-15-28/
# 27052  results/SL_всеЮИ2022-09-01-15-28/
# 27971  results/SL_всеЮИ2022-09-01-15-28/
# 28587  results/SL_всеЮИ2022-09-01-15-28/
# 29494  results/SL_всеЮИ2022-09-01-15-28/
# 30710  results/SL_всеЮИ2022-09-01-15-28/
# 30743  results/SL_всеЮИ2022-09-01-15-28/
# 31640  results/SL_всеЮИ2022-09-01-15-28/
# 32074  results/SL_всеЮИ2022-09-01-15-28/
# 33671  results/SL_всеЮИ2022-09-01-15-28/
# 33967  results/SL_всеЮИ2022-09-01-15-28/
# 34151  results/SL_всеЮИ2022-09-01-15-28/
# 34716  results/SL_всеЮИ2022-09-01-15-28/
# 34927  results/SL_всеЮИ2022-09-01-15-28/
# 35572  results/SL_всеЮИ2022-09-01-15-28/
#
#                                         filname vidizd0
# 407     SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 815     SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 1629    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 2275    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 2931    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 3258    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 3562    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 4757    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 5278    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 5284    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 5424    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 5794    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 6978    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 8686    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 9038    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 9495    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 11042   SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Ножной
# 12747  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 13407  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 14896  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 14973  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 15085  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 15323  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 15789  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 15901  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 16029  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 18152  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 18185  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 19226  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 19763  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 20051  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 21212  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 21660  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 22364  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 24393  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 25596  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 27052  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 27971  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 28587  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 29494  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 30710  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 30743  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 31640  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 32074  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 33671  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 33967  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 34151  SL_всеЮИ2022-09-01-16-15_13100-35700.csv  Ножной
# 34716     _reserve_SL_всеЮИ2022-09-08-12-45.csv  Ножной
# 34927     _reserve_SL_всеЮИ2022-09-08-12-45.csv  Ножной
# 35572     _reserve_SL_всеЮИ2022-09-08-12-45.csv  Ножной

# %%
df[df['vidizd0'] == 'Серьга']
# Out:
#                                           h1      art  price  price2  \
# 291                        Серебряная серьга   270851   294₽    980₽
# 368               Золотая серьга с фианитами   262321  1494₽   4980₽
# 415                           Золотая серьга   333325  2994₽   9980₽
# 506            Серебряная серьга с фианитами   313005  3590₽   7180₽
# 1129              Золотая серьга с фианитами   261043  4794₽  15980₽
# ...                                      ...      ...    ...     ...
# 34857                      Серебряная серьга    99257   690₽   1380₽
# 35053             Золотые серьги с фианитами   312848  6490₽  12980₽
# 35098                      Серебряная серьга   306813   790₽   1580₽
# 35104  Золотая серьга с кубическим цирконием   328217  9490₽  18980₽
# 35312          Серебряная серьга с фианитами   309471  1790₽   3580₽
#
#                                                                                                                                                                                                           gold  \
# 291                                                                                                           Артикул: 270851;Серьга    \nСеребро 925 пробы.;Вес изделия: 0.28г;Серьга    \nСеребро 925 пробы.
# 368                                                       Артикул: 262321;Серьга, вставка:  фианит;    \nРозовое золото 585 пробы.;Вес изделия: 0.21г;Серьга, вставка:  фианит;    \nРозовое золото 585 пробы.
# 415                                                                                               Артикул: 333325;Серьга    \nЖелтое золото 585 пробы.;Вес изделия: 0.72г;Серьга    \nЖелтое золото 585 пробы.
# 506                                                                      Артикул: 313005;Серьга, вставка:  фианит;    \nСеребро 925 пробы.;Вес изделия: 2.4г;Серьга, вставка:  фианит;    \nСеребро 925 пробы.
# 1129                                                      Артикул: 261043;Серьга, вставка:  фианит;    \nРозовое золото 585 пробы.;Вес изделия: 0.53г;Серьга, вставка:  фианит;    \nРозовое золото 585 пробы.
# ...                                                                                                                                                                                                        ...
# 34857                                                                                                          Артикул: 99257;Серьга    \nСеребро 925 пробы.;Вес изделия: 0.66г;Серьга    \nСеребро 925 пробы.
# 35053  Артикул: 312848;Серьга, вставка:  фианит;    \nРозовое золото 585 пробы.\n\nТрендовые золотые украшения. Стильные украшения – обязательный элемент модного образа. Кольца и браслеты, колье и серьги...
# 35098                                                                                                         Артикул: 306813;Серьга    \nСеребро 925 пробы.;Вес изделия: 0.75г;Серьга    \nСеребро 925 пробы.
# 35104                         Артикул: 328217;Серьга, вставка:  куб.цирконий зеленый;    \nРозовое золото 585 пробы.;Вес изделия: 1.13г;Серьга, вставка:  куб.цирконий зеленый;    \nРозовое золото 585 пробы.
# 35312  Артикул: 309471;Серьга, вставка:  фианит;    \nСеребро 925 пробы.\n\nРазнообразьте свой образ вместе с SUNLIGHT! В этом Вам помогут каффы, которые являются уже настоящим мастхэвом сезона. Удобство...
#
#        gold2  weight  gems  gems2  \
# 291      NaN     NaN   NaN    NaN
# 368      NaN     NaN   NaN    NaN
# 415      NaN     NaN   NaN    NaN
# 506      NaN     NaN   NaN    NaN
# 1129     NaN     NaN   NaN    NaN
# ...      ...     ...   ...    ...
# 34857    NaN     NaN   NaN    NaN
# 35053    NaN     NaN   NaN    NaN
# 35098    NaN     NaN   NaN    NaN
# 35104    NaN     NaN   NaN    NaN
# 35312    NaN     NaN   NaN    NaN
#
#                                                         url  \
# 291    https://sunlight.net/catalog/one_earring_270851.html
# 368    https://sunlight.net/catalog/one_earring_262321.html
# 415    https://sunlight.net/catalog/one_earring_333325.html
# 506        https://sunlight.net/catalog/earring_313005.html
# 1129   https://sunlight.net/catalog/one_earring_261043.html
# ...                                                     ...
# 34857  https://sunlight.net/catalog/one_earring_269001.html
# 35053      https://sunlight.net/catalog/earring_312848.html
# 35098      https://sunlight.net/catalog/earring_306813.html
# 35104      https://sunlight.net/catalog/earring_328217.html
# 35312      https://sunlight.net/catalog/earring_309471.html
#
#                                                                     d1  \
# 291                                   Т740028035&РОССИЯ&Серебро&0.28 г
# 368                          11866-S5R-01&Розовое золото&Фианит&0.21 г
# 415                 097820_02_03_000_0000*&РОССИЯ&Желтое золото&0.72 г
# 506                             27 367 061&РОССИЯ&Серебро&Фианит&2.4 г
# 1129                         11833-S5R-01&Розовое золото&Фианит&0.53 г
# ...                                                                ...
# 34857                                     S11163-S9W-01&Серебро&0.66 г
# 35053                S-130009_001*&РОССИЯ&Розовое золото&Фианит&0.81 г
# 35098                                    2-9227л&РОССИЯ&Серебро&0.75 г
# 35104  04-62-0195-05*&РОССИЯ&Розовое золото&Кубический цирконий&1.13 г
# 35312                              S55223-S9W-01&Серебро&Фианит&1.27 г
#
#                                                   d0  \
# 291                SERGEY GRIBNYAKOV&ПИРСИНГ СЕРЕБРО
# 368                 SERGEY GRIBNYAKOV&Пирсинг Золото
# 415          SERGEY GRIBNYAKOV&Белое и желтое золото
# 506                           Markiz&ПИРСИНГ СЕРЕБРО
# 1129                SERGEY GRIBNYAKOV&Пирсинг Золото
# ...                                              ...
# 34857              SERGEY GRIBNYAKOV&ПИРСИНГ СЕРЕБРО
# 35053  SERGEY GRIBNYAKOV&Трендовые золотые украшения
# 35098              SERGEY GRIBNYAKOV&ПИРСИНГ СЕРЕБРО
# 35104                        SUNLIGHT&Пирсинг Золото
# 35312              SERGEY GRIBNYAKOV&ПИРСИНГ СЕРЕБРО
#
#                                   source  \
# 291    results/SL_всеЮИ2022-09-01-15-28/
# 368    results/SL_всеЮИ2022-09-01-15-28/
# 415    results/SL_всеЮИ2022-09-01-15-28/
# 506    results/SL_всеЮИ2022-09-01-15-28/
# 1129   results/SL_всеЮИ2022-09-01-15-28/
# ...                                  ...
# 34857  results/SL_всеЮИ2022-09-01-15-28/
# 35053  results/SL_всеЮИ2022-09-01-15-28/
# 35098  results/SL_всеЮИ2022-09-01-15-28/
# 35104  results/SL_всеЮИ2022-09-01-15-28/
# 35312  results/SL_всеЮИ2022-09-01-15-28/
#
#                                        filname vidizd0
# 291    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Серьга
# 368    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Серьга
# 415    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Серьга
# 506    SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Серьга
# 1129   SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Серьга
# ...                                        ...     ...
# 34857    _reserve_SL_всеЮИ2022-09-08-12-45.csv  Серьга
# 35053    _reserve_SL_всеЮИ2022-09-08-12-45.csv  Серьга
# 35098    _reserve_SL_всеЮИ2022-09-08-12-45.csv  Серьга
# 35104    _reserve_SL_всеЮИ2022-09-08-12-45.csv  Серьга
# 35312    _reserve_SL_всеЮИ2022-09-08-12-45.csv  Серьга
#
# [170 rows x 15 columns]

# %%
pattern_gold = r'[Сс]ереб\w+|[Зз]олот\w*|[Сс]таль|[Пп]латин'
pattern_diam = r'[Бб]риллиант\w*'
pattern_probe = r'[\d]{,3}(?=\s*проб)'
pattern_gramm = r'[\d.\d]{,5}(?=г;)'
pattern_vst = r'вставк\w*'#r'вставк\w*'
pattern_type = r'(?<=;)\w+\s?\w*'
def gold(t,patt):
    f = re.search(patt,t)
    return f.group() if f else 're не найдено'

# %%
t = 'Артикул: 114165;Кольцо    \nБелое золото 585 пробы.;Вес изделия: 3.04г;Кольцо    \nБелое золото 585 пробы.'
re.search(pattern_type,t)
# Out:
# <re.Match object; span=(16, 23), match='Кольцо '>

# %%
patt = pattern_gold
#patt = pattern_type
#patt = pattern_diam

# %%
patt
# Out:
# '[Сс]ереб\\w+|[Зз]олот\\w*|[Сс]таль|[Пп]латин'

# %%
i = 100

gold(df.gold.loc[i],patt), df.gold.loc[i]
# Out:
# ('золото',
#  'Артикул: 109122;Браслет с 12 бриллиантами, огранка круг 17 граней, 0.04 карат, цвет 2, чистота 2, тип огранки Б;\n1 изумрудом, 0.08 карат, цвет 3, чистота 3, тип огранки В;    \nРозовое золото 585 пробы.;Вес изделия: 6.02г;Браслет с 12 бриллиантами, огранка круг 17 граней, 0.04 карат, цвет 2, чистота 2, тип огранки Б;\n1 изумрудом, 0.08 карат, цвет 3, чистота 3, тип огранки В;    \nРозовое золото 585 пробы.')

# %%
df.gold.apply(lambda x: gold(x, patt)).unique()
# Out:
# array(['re не найдено', 'золото', 'Серебро', 'золотые', 'Сталь', 'Золото',
#        'серебра', 'серебро', 'сталь', 'Серебряная', 'золотых', 'золотую',
#        'золотой', 'серебре', 'золота'], dtype=object)

# %%
patt
# Out:
# '[Сс]ереб\\w+|[Зз]олот\\w*|[Сс]таль'

# %%
df.h1.apply(lambda x: gold(x, patt)).value_counts()
# Out:
# Золотые          7556
# Золотое          6674
# Серебряное       6411
# Серебряные       6325
# Золотая          3444
# Серебряная       2364
# Серебряный       1458
# Золотой          1219
# Платин             70
# серебряным         49
# re не найдено      33
# золотым            20
# серебряной         11
# Сталь               4
# золота              3
# золотыми            2
# золотой             2
# серебряных          1
# золотое             1
# Name: h1, dtype: int64

# %%
df.goldsilv.value_counts()# == 're не найдено']
# Out:
# Золотые          7556
# Золотое          6674
# Серебряное       6411
# Серебряные       6325
# Золотая          3444
# Серебряная       2364
# Серебряный       1458
# Золотой          1219
# re не найдено     102
# серебряным         49
# золотым            20
# серебряной         11
# Сталь               4
# золота              3
# золотой             3
# золотыми            2
# серебряных          1
# золотое             1
# Name: goldsilv, dtype: int64

# %%
data[data.gold.apply(lambda x: gold(x, patt))=='Ножной']

# %% [markdown]
# # Сборки функций

# %% [markdown]
# ## После тестирования

# %%
import pandas as pd
#readme 
def choosefile(io=None):
    '''
    v22-10-13
    Signature:
        choosefile(
        io = None )
        ) -> Tuple[path:str,filename:str,exstention:str]
    Docstring:
        Предлагает папки и файлы - возвращает путь, имя файла без расширения и расширение, 
        если в параметре указан io то не предлагает, а раскладывает указанный io
    Parameters
    ----------
    io : str, bytes, ExcelFile, xlrd.Book, path object, or file-like object
    Any valid string path is acceptable. The string could be a URL. Valid
    URL schemes include http, ftp, s3, and file. For file URLs, a host is
    expected. A local file could be: ``file://localhost/path/to/table.xlsx``.
    '''
    import os
    if io:
        path =  io.split('/')[:-1]
        filename = io.split('/')[-1].split('.')[:-1]
        fileexst = io.split('.')[-1]
        return ('/'.join(path),'.'.join(filename),fileexst)
    else:
        print(os.listdir())
        return ('_','_','_')
    
def check_columns(data, controlcolumns, ignore_extra = True):
    '''
    v22-10-12
    Signature:
        check_columns(
        data: 'DataFrame',
        controlcolumns: 'list-like'
        ignore_extra = True
        ) -> 'bool'
    Docstring:
        Проверяет соответствие столбцов в обрабатываемом файле, 
        по умолчанию игнорирует избыточные столбцы
    Parametrs
    ---------
        data: DataFrame
        controlcolumns: 'list-like'
            должны содержаться эти столбцы
        ignore_extra: bool, default True
            игнорирует избыточные столбцы
    Returns
    -------
        True|False
    '''
    set_data_columns = set(data.columns)
    set_columns = set (controlcolumns)
    if ignore_extra:
        return set_columns.issubset(set_data_columns)
    else:
        return set_columns == set_data_columns
    

def firstclear(df):
    '''
    v22-10-12
    Signature:
        first_clear(
        df: 'DataFrame',
        ) -> 'DataFrame'
    Docstring:
        Удаляет неинформативные данные с пустой ценой с df, возвращает удаленные в виде 
        DataFrame
    Parametrs
    ---------
        df: DataFrame
    
    Returns
    -------
        DataFrame
    '''
    deleted = df[df['price'].isna()]
    df.dropna(subset=['price'], inplace=True)
    return deleted

# %%
import os

# %% [markdown]
# ## Не тестированные

# %%
#PCH01-09-2022
def byrepost(data):
    def gold(t, patt):
        f = re.search(patt, t)
        return f.group() if f else 're не найдено'

    pattern_gold = r'[Сс]ереб\w+|[Зз]олот\w*|[Сс]таль|[Пп]латин'
    pattern_diam = r'[Бб]риллиант\w*'
    pattern_probe = r'[\d]{,3}(?=\s*проб)'
    pattern_gramm = r'[\d.\d]{,5}(?=г;)'
    pattern_vst = r'вставк\w*'  # r'вставк\w*'
    pattern_type = r'(?<=;)\w+\s?\w*'

    data['diam'] = data.gold.apply(lambda x: gold(x, pattern_diam))
    data['goldsilv'] = data.h1.apply(lambda x: gold(x, pattern_gold))
    data['probe'] = data.gold.apply(lambda x: gold(x, pattern_probe))
    data['gramm'] = data.gold.apply(lambda x: gold(x, pattern_gramm))
    data['vst'] = data.gold.apply(lambda x: gold(x, pattern_vst))
    data['type'] = data.gold.apply(lambda x: gold(x, pattern_type))

# %% [markdown]
# # Сборка main

# %%
import pandas as pd
if __name__=='__main__':
    source, filename, fileexst = \
    choosefile('results/SL_всеЮИ2022-09-01-15-28/_joined-2022-09-09-10-18.xlsx')
    df = pd.read_excel(source+'/'+filename+'.'+fileexst)
    controlcolumns = {'art', 'd0', 'd1', 'filname', 'gems', 'gems2', 'gold',
     'gold2', 'h1', 'price', 'price2', 'source', 'url', 'weight'}
    if not check_columns(df, controlcolumns):
        print('не соответствуют столбцы\n', controlcolumns)
        raise Exception('error columns')
        
    deldf = firstclear(df)
    
    print(f"прочитано всего {len(df)}, отброшено как не информативные {len(deldf)}")
# Out:
# прочитано всего 35647, отброшено как не информативные 8

# %%
len(firstclear(df))
# Out:
# 0

# %%
byrepost(df)

# %%
df
# Out:
#                                                 h1      art    price   price2  \
# 0                       Золотое кольцо с фианитами    68001    6294₽   20980₽
# 1      Золотой браслет с изумрудами и бриллиантами   109122   35994₽  119980₽
# 2                                Серебряное кольцо   289895     894₽    2980₽
# 3                     Серебряные серьги с топазами   316910    1914₽    6380₽
# 4                    Серебряное кольцо с аметистом   290202    3594₽   11980₽
# ...                                            ...      ...      ...      ...
# 35650                            Серебряные серьги   263346    1990₽    3980₽
# 35651           Золотые серьги «Бриллианты Якутии»   154739  244990₽  489980₽
# 35652         Золотое шейное украшение с фианитами   253794   15110₽   50367₽
# 35653       Серебряное кольцо с эмалью и фианитами    83715    1190₽    3967₽
# 35654                   Золотые серьги с фианитами   279395   13490₽   44967₽
#
#                                                                                                                                                                                                           gold  \
# 0                                                                                      Артикул: 68001;Кольцо, вставка:  фианит;    \n 585 пробы.;Вес изделия: 1.04г;Кольцо, вставка:  фианит;    \n 585 пробы.
# 1      Артикул: 109122;Браслет с 12 бриллиантами, огранка круг 17 граней, 0.04 карат, цвет 2, чистота 2, тип огранки Б;\n1 изумрудом, 0.08 карат, цвет 3, чистота 3, тип огранки В;    \nРозовое золото 585...
# 2                                                                                                             Артикул: 289895;Кольцо    \nСеребро 925 пробы.;Вес изделия: 3.89г;Кольцо    \nСеребро 925 пробы.
# 3                                                                           Артикул: 316910;Серьги, вставка:  топаз;   \nСеребро 925 пробы.;Вес изделия: 2.94г;Серьги, вставка:  топаз;   \nСеребро 925 пробы.
# 4                                                                     Артикул: 290202;Кольцо, вставка:  аметист;    \nСеребро 925 пробы.;Вес изделия: 5.66г;Кольцо, вставка:  аметист;    \nСеребро 925 пробы.
# ...                                                                                                                                                                                                        ...
# 35650                                                                                                         Артикул: 263346;Серьги    \nСеребро 925 пробы.;Вес изделия: 3.95г;Серьги    \nСеребро 925 пробы.
# 35651  Артикул: 154739;Серьги «Бриллианты Якутии» с 2 бриллиантами, огранка круг 57 граней, 0.63 карат, цвет 3, чистота 6, тип огранки А; \nБелое золото 585 пробы;Вес изделия: 1.7г;Серьги «Бриллианты Яку...
# 35652                                             Артикул: 253794;Шейное укр., вставка:  фианит;    \nЖелтое золото 585 пробы.;Вес изделия: 3.27г;Шейное укр., вставка:  фианит;    \nЖелтое золото 585 пробы.
# 35653  Артикул: 83715;Кольцо, вставка:  фианит; эмаль;    \nСеребро 925 пробы.\n\nЮвелирные украшения с эмалью завораживают своей изысканностью и красотой. Создание украшений с эмалью - один из самых сло...
# 35654  Артикул: 279395;Серьги, вставка:  фианит;    \nРозовое золото 585 пробы.\n\nКостромские ювелирные украшения: традиционный русский стиль -  Коллекция украшений с традиционными русскими дизайнами. У...
#
#        gold2  weight  gems  gems2  \
# 0        NaN     NaN   NaN    NaN
# 1        NaN     NaN   NaN    NaN
# 2        NaN     NaN   NaN    NaN
# 3        NaN     NaN   NaN    NaN
# 4        NaN     NaN   NaN    NaN
# ...      ...     ...   ...    ...
# 35650    NaN     NaN   NaN    NaN
# 35651    NaN     NaN   NaN    NaN
# 35652    NaN     NaN   NaN    NaN
# 35653    NaN     NaN   NaN    NaN
# 35654    NaN     NaN   NaN    NaN
#
#                                                             url  ...  \
# 0                  https://sunlight.net/catalog/ring_68001.html  ...
# 1            https://sunlight.net/catalog/bracelets_109122.html  ...
# 2                 https://sunlight.net/catalog/ring_289895.html  ...
# 3              https://sunlight.net/catalog/earring_316910.html  ...
# 4                 https://sunlight.net/catalog/ring_290202.html  ...
# ...                                                         ...  ...
# 35650          https://sunlight.net/catalog/earring_263346.html  ...
# 35651          https://sunlight.net/catalog/earring_154739.html  ...
# 35652  https://sunlight.net/catalog/neck_decoration_253794.html  ...
# 35653              https://sunlight.net/catalog/ring_83715.html  ...
# 35654          https://sunlight.net/catalog/earring_279395.html  ...
#
#                                                    d0  \
# 0             SERGEY GRIBNYAKOV&Белое и желтое золото
# 1                  SERGEY GRIBNYAKOV&Золото. Изумруды
# 2      SERGEY GRIBNYAKOV&Гладкие серебряные украшения
# 3                          SERGEY GRIBNYAKOV&NATURIKA
# 4                                      Balex&NATURIKA
# ...                                               ...
# 35650  SERGEY GRIBNYAKOV&Гладкие серебряные украшения
# 35651             Бриллианты Якутии&Бриллианты Якутии
# 35652                               JASMİNE JEWELLERY
# 35653                 SERGEY GRIBNYAKOV&Эмаль Серебро
# 35654                               SERGEY GRIBNYAKOV
#
#                                   source  \
# 0      results/SL_всеЮИ2022-09-01-15-28/
# 1      results/SL_всеЮИ2022-09-01-15-28/
# 2      results/SL_всеЮИ2022-09-01-15-28/
# 3      results/SL_всеЮИ2022-09-01-15-28/
# 4      results/SL_всеЮИ2022-09-01-15-28/
# ...                                  ...
# 35650  results/SL_всеЮИ2022-09-01-15-28/
# 35651  results/SL_всеЮИ2022-09-01-15-28/
# 35652  results/SL_всеЮИ2022-09-01-15-28/
# 35653  results/SL_всеЮИ2022-09-01-15-28/
# 35654  results/SL_всеЮИ2022-09-01-15-28/
#
#                                        filname  vidizd0           diam  \
# 0      SL_всеЮИ2022-09-01-16-15-1251-12952.csv   Кольцо  re не найдено
# 1      SL_всеЮИ2022-09-01-16-15-1251-12952.csv  Браслет   бриллиантами
# 2      SL_всеЮИ2022-09-01-16-15-1251-12952.csv   Кольцо  re не найдено
# 3      SL_всеЮИ2022-09-01-16-15-1251-12952.csv   Серьги  re не найдено
# 4      SL_всеЮИ2022-09-01-16-15-1251-12952.csv   Кольцо  re не найдено
# ...                                        ...      ...            ...
# 35650    _reserve_SL_всеЮИ2022-09-08-12-45.csv   Серьги  re не найдено
# 35651    _reserve_SL_всеЮИ2022-09-08-12-45.csv   Серьги     Бриллианты
# 35652    _reserve_SL_всеЮИ2022-09-08-12-45.csv   Шейное  re не найдено
# 35653    _reserve_SL_всеЮИ2022-09-08-12-45.csv   Кольцо  re не найдено
# 35654    _reserve_SL_всеЮИ2022-09-08-12-45.csv   Серьги  re не найдено
#
#          goldsilv probe gramm            vst        type
# 0         Золотое   585  1.04        вставка      Кольцо
# 1         Золотой   585  6.02  re не найдено   Браслет с
# 2      Серебряное   925  3.89  re не найдено     Кольцо
# 3      Серебряные   925  2.94        вставка      Серьги
# 4      Серебряное   925  5.66        вставка      Кольцо
# ...           ...   ...   ...            ...         ...
# 35650  Серебряные   925  3.95  re не найдено     Серьги
# 35651     Золотые   585   1.7  re не найдено     Серьги
# 35652     Золотое   585  3.27        вставка  Шейное укр
# 35653  Серебряное   925  5.66        вставка      Кольцо
# 35654     Золотые   585  3.22        вставка      Серьги
#
# [35647 rows x 21 columns]

# %%
df.to_excel('_promres22-10-12-16-00.xlsx')

# %% [markdown]
# # CHAOSSSS

# %% [markdown]
# ## Код для перезапуска модулей и классов

# %%
import importlib

# %%
import modules.dicts.classes_dicts, modules.dicts.classes_site #https://stackoverflow.com/questions/6946376/how-to-reload-a-class-in-python-shell

# %%
importlib.reload(modules.dicts.classes_dicts)
# Out:
# <module 'modules.dicts.classes_dicts' from 'C:\\Users\\специалист ао\\mypandas\\work\\CDO2030\\Parsing_NKO\\modules\\dicts\\classes_dicts.py'>

# %%
importlib.reload(modules.dicts.classes_site)
# Out:
# <module 'modules.dicts.classes_site' from 'C:\\Users\\специалист ао\\mypandas\\work\\CDO2030\\Parsing_NKO\\modules\\dicts\\classes_site.py'>

# %%
from modules.dicts.classes_dicts import Dtask,Dicts

# %%
from modules.dicts.classes_site import Site

# %% [markdown]
# ## Модули

# %%
import datetime
import json
import os
import re
import requests
from requests import Request, Session
from bs4 import BeautifulSoup
import pandas as pd

from modules.dicts.classes_dicts import Dtask,Dicts
from modules.dicts.classes_site import Site

# %% [markdown]
# # Разработка класса просмотр задач

# %%
folder = 'tasklogs/'
files = os.listdir(folder)

# %%
files = os.listdir(folder)

# %%
pd.read_csv(folder+files[0])
# Out:
# Empty DataFrame
# Columns: [{"name": "SL_diamonds",  "domain": "https://sunlight.net/",  "urls0": "https://sunlight.net/catalog/diamonds-all.html",  "urlslast": "https://sunlight.net/catalog/diamonds-all/page-4/",  "descr": "",  "datestr0": "2022-09-06-22-58",  "datestr": "2022-09-06-23-02",  "links": ["/catalog/ring_165495.html",  "/catalog/ring_146537.html",  "/catalog/ring_57830.html",  "/catalog/ring_47720.html",  "/catalog/ring_108790.html",  "/catalog/ring_109474.html",  "/catalog/ring_108796.html",  "/catalog/ring_152015.html",  "/catalog/ring_56703.html",  "/catalog/ring_48271.html",  "/catalog/earring_108798.html",  "/catalog/ring_238293.html",  "/catalog/ring_283369.html",  "/catalog/ring_69240.html",  "/catalog/ring_56676.html",  "/catalog/earring_48270.html",  "/catalog/earring_47719.html",  "/catalog/ring_100269.html",  "/catalog/ring_234085.html",  "/catalog/earring_146521.html",  "/catalog/earring_56677.html",  "/catalog/earring_146538.html",  "/catalog/ring_61080.html",  "/catalog/pendants_78054.html",  "/catalog/ring_75616.html",  "/catalog/ring_57753.html",  "/catalog/pendants_290415.html",  "/catalog/earring_285237.html",  "/catalog/ring_108063.html",  "/catalog/ring_69239.html",  "/catalog/earring_58796.html",  "/catalog/earring_108791.html",  "/catalog/ring_58795.html",  "/catalog/ring_93264.html",  "/catalog/pendants_78052.html",  "/catalog/earring_69242.html",  "/catalog/earring_75617.html",  "/catalog/ring_276995.html",  "/catalog/pendants_45211.html",  "/catalog/earring_100270.html",  "/catalog/earring_286758.html",  "/catalog/earring_69241.html",  "/catalog/pendants_63494.html",  "/catalog/earring_81222.html",  "/catalog/earring_276996.html",  "/catalog/earring_93288.html",  "/catalog/earring_108064.html",  "/catalog/earring_58181.html",  "/catalog/earring389.html",  "/catalog/pendants_312887.html",  "/catalog/ring_92006.html",  "/catalog/ring_76218.html",  "/catalog/earring_76219.html",  "/catalog/pendants_279448.html",  "/catalog/ring_277113.html",  "/catalog/earring_81220.html",  "/catalog/ring_83601.html",  "/catalog/earring_81221.html",  "/catalog/earring_92680.html",  "/catalog/earring_146527.html",  "/catalog/pendants_58553.html",  "/catalog/ring_146526.html",  "/catalog/ring_273388.html",  "/catalog/ring_51292.html",  "/catalog/ring_280238.html",  "/catalog/pendants_50906.html",  "/catalog/earring_275421.html",  "/catalog/ring_125960.html",  "/catalog/pendants_57784.html",  "/catalog/ring_313658.html",  "/catalog/pendants_58552.html",  "/catalog/earring_51456.html",  "/catalog/earring_66871.html",  "/catalog/ring_66502.html",  "/catalog/ring_307734.html",  "/catalog/ring_275418.html",  "/catalog/earring_123837.html",  "/catalog/earring_56508.html",  "/catalog/ring_157318.html",  "/catalog/ring_99436.html",  "/catalog/ring_58133.html",  "/catalog/pendants_66503.html",  "/catalog/earring_55920.html",  "/catalog/ring_76111.html",  "/catalog/earring_272173.html",  "/catalog/ring_108792.html",  "/catalog/ring_58184.html",  "/catalog/ring_112488.html",  "/catalog/ring_99435.html",  "/catalog/pendants_51455.html",  "/catalog/ring206665.html",  "/catalog/ring_157335.html",  "/catalog/ring_71585.html", ...]
# Index: []
#
# [0 rows x 187 columns]

# %%
taskx = Dtask({})
# Out:
# установка : name2022-09-09-16-03

# %%
taskx.load(files[3],'name')
d = taskx.dict

# %%
if 'links' in d.keys():
    del d['links']

# %%
taskx.print()
# Out:
# task name: name2022-09-09-16-03
# links len =  120
#
# {'name': 'SL_diamonds2022-09-07-12-41',
# 'domain': 'https://sunlight.net/',
# 'urls0': 'https://sunlight.net/catalog/diamonds-all.html',
# 'urlslast': 'https://sunlight.net/catalog/diamonds-all/page-3/',
# 'descr': '',
# 'datestr0': '2022-09-07-12-41',
# 'datestr': '2022-09-07-12-51',
# 'parcing': 'results//_reserve_SL_diamonds2022-09-07-12-412022-09-07-12-51.csv',
# }

# %%
pd.DataFrame(taskx.dict)
# Out:
#                             name                 domain  \
# 0    SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 1    SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 2    SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 3    SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 4    SL_diamonds2022-09-07-12-41  https://sunlight.net/
# ..                           ...                    ...
# 115  SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 116  SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 117  SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 118  SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 119  SL_diamonds2022-09-07-12-41  https://sunlight.net/
#
#                                               urls0  \
# 0    https://sunlight.net/catalog/diamonds-all.html
# 1    https://sunlight.net/catalog/diamonds-all.html
# 2    https://sunlight.net/catalog/diamonds-all.html
# 3    https://sunlight.net/catalog/diamonds-all.html
# 4    https://sunlight.net/catalog/diamonds-all.html
# ..                                              ...
# 115  https://sunlight.net/catalog/diamonds-all.html
# 116  https://sunlight.net/catalog/diamonds-all.html
# 117  https://sunlight.net/catalog/diamonds-all.html
# 118  https://sunlight.net/catalog/diamonds-all.html
# 119  https://sunlight.net/catalog/diamonds-all.html
#
#                                               urlslast descr  \
# 0    https://sunlight.net/catalog/diamonds-all/page-3/
# 1    https://sunlight.net/catalog/diamonds-all/page-3/
# 2    https://sunlight.net/catalog/diamonds-all/page-3/
# 3    https://sunlight.net/catalog/diamonds-all/page-3/
# 4    https://sunlight.net/catalog/diamonds-all/page-3/
# ..                                                 ...   ...
# 115  https://sunlight.net/catalog/diamonds-all/page-3/
# 116  https://sunlight.net/catalog/diamonds-all/page-3/
# 117  https://sunlight.net/catalog/diamonds-all/page-3/
# 118  https://sunlight.net/catalog/diamonds-all/page-3/
# 119  https://sunlight.net/catalog/diamonds-all/page-3/
#
#              datestr0           datestr                          links  \
# 0    2022-09-07-12-41  2022-09-07-12-51      /catalog/ring_165495.html
# 1    2022-09-07-12-41  2022-09-07-12-51      /catalog/ring_146537.html
# 2    2022-09-07-12-41  2022-09-07-12-51       /catalog/ring_57830.html
# 3    2022-09-07-12-41  2022-09-07-12-51       /catalog/ring_47720.html
# 4    2022-09-07-12-41  2022-09-07-12-51      /catalog/ring_108790.html
# ..                ...               ...                            ...
# 115  2022-09-07-12-41  2022-09-07-12-51    /catalog/earring_54694.html
# 116  2022-09-07-12-41  2022-09-07-12-51    /catalog/earring_69297.html
# 117  2022-09-07-12-41  2022-09-07-12-51  /catalog/pendants_108794.html
# 118  2022-09-07-12-41  2022-09-07-12-51    /catalog/earring_71405.html
# 119  2022-09-07-12-41  2022-09-07-12-51   /catalog/earring_313143.html
#
#                                                parcing
# 0    results//_reserve_SL_diamonds2022-09-07-12-412...
# 1    results//_reserve_SL_diamonds2022-09-07-12-412...
# 2    results//_reserve_SL_diamonds2022-09-07-12-412...
# 3    results//_reserve_SL_diamonds2022-09-07-12-412...
# 4    results//_reserve_SL_diamonds2022-09-07-12-412...
# ..                                                 ...
# 115  results//_reserve_SL_diamonds2022-09-07-12-412...
# 116  results//_reserve_SL_diamonds2022-09-07-12-412...
# 117  results//_reserve_SL_diamonds2022-09-07-12-412...
# 118  results//_reserve_SL_diamonds2022-09-07-12-412...
# 119  results//_reserve_SL_diamonds2022-09-07-12-412...
#
# [120 rows x 9 columns]

# %%
pd.DataFrame(pd.Series(t.dict)).T
# Out:
#        name                                              links  \
# 0  SL_всеЮИ  [/catalog/earring_75382.html, /catalog/ring_28...
#
#             datestr                                               urls  \
# 0  2022-09-01-16-15  https://sunlight.net/catalog/?material=326,327...
#
#                  domain                                          taskdescr
# 0  https://sunlight.net  579 стр с фильтром https://sunlight.net/catalo...

# %%
folder = 'tasklogs/'
files = os.listdir(folder)
ldict = []
taskx = Dtask({})
for f in files:
    taskx.load(f,'name')
    d = taskx.dict
    if 'links' in d.keys():
        del d['links']
    ldict.append(pd.DataFrame(pd.Series(d)).T)
# Out:
# установка : name2022-09-08-15-01

# %%
pd.concat(ldict).sort_values(by='datestr0')
# Out:
#                           name                 domain  \
# 0                  SL_diamonds  https://sunlight.net/
# 0                  SL_diamonds  https://sunlight.net/
# 0                  SL_diamonds  https://sunlight.net/
# 0  SL_diamonds2022-09-07-08-24  https://sunlight.net/
# 0  SL_diamonds2022-09-07-12-41  https://sunlight.net/
# 0  SL_diamonds2022-09-07-17-29  https://sunlight.net/
# 0                     SL_всеЮИ   https://sunlight.net
#
#                                             urls0  \
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0  https://sunlight.net/catalog/diamonds-all.html
# 0                                             NaN
#
#                                             urlslast descr          datestr0  \
# 0  https://sunlight.net/catalog/diamonds-all/page-4/        2022-09-06-22-58
# 0  https://sunlight.net/catalog/diamonds-all/page-4/        2022-09-06-22-58
# 0  https://sunlight.net/catalog/diamonds-all/page-4/        2022-09-07-06-31
# 0  https://sunlight.net/catalog/diamonds-all/page-4/        2022-09-07-08-24
# 0  https://sunlight.net/catalog/diamonds-all/page-3/        2022-09-07-12-41
# 0  https://sunlight.net/catalog/diamonds-all/page-3/        2022-09-07-17-29
# 0                                                NaN   NaN               NaN
#
#             datestr                                            parcing  \
# 0  2022-09-06-23-02                                                NaN
# 0  2022-09-07-08-07  results//_reserve_SL_diamonds2022-09-07-08-07.csv
# 0  2022-09-07-06-34                                                NaN
# 0  2022-09-07-08-25                                                NaN
# 0  2022-09-07-12-51  results//_reserve_SL_diamonds2022-09-07-12-412...
# 0  2022-09-07-17-34  results//_reserve_SL_diamonds2022-09-07-17-292...
# 0  2022-09-01-16-15                                                NaN
#
#                                                 urls  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  https://sunlight.net/catalog/?material=326,327...
#
#                                            taskdescr
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0  579 стр с фильтром https://sunlight.net/catalo...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
with os.scandir() as it:
    for n, entry in enumerate(it):
        if not entry.name.startswith('.') and not entry.is_file():
            print(n, entry.name)
# Out:
# 13 env
# 15 jewels
# 16 links
# 17 modules
# 30 results
# 32 rusprice
# 33 tasklogs
# 39 __pycache__
# 40 Новая папка

# %%
files = [i.name for i in os.scandir() if not i.name.startswith('.') and i.is_dir()]
print(*[(n,f) for n,f in enumerate(files)], sep = '\n')
# Out:
# (0, 'env')
# (1, 'jewels')
# (2, 'links')
# (3, 'modules')
# (4, 'results')
# (5, 'rusprice')
# (6, 'tasklogs')
# (7, '__pycache__')
# (8, 'Новая папка')

# %%
files[6]
# Out:
# 'tasklogs'

# %%
with os.scandir('results') as it:
    for entry in it:
        if not entry.name.startswith('.') and not entry.is_file():
            print(entry.name)
# Out:
# del
# SL_всеЮИ2022-09-01-15-28

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.git',
#  '.idea',
#  '.ipynb_checkpoints',
#  'AnaliticRep031221.ipynb',
#  'AnaliticRep060622EPL_Кольца_с_брилл-62.ipynb',
#  'AnaliticRep061221-KDM1C8.ipynb',
#  'AnaliticRep140422MUIZ_Кольца_с_брилл.ipynb',
#  'AnaliticRep220422EGELGE_брилл.ipynb',
#  'AnaliticRep240522MUIZ_Кольца_с_брилл.ipynb',
#  'collectxls_reps.ipynb',
#  'data.xlsx',
#  'Egelge_1after_parsing.ipynb',
#  'env',
#  'for_parsing_func.ipynb',
#  'jewels',
#  'links',
#  'modules',
#  'MUIZ_justcode.ipynb',
#  'Parsing.html',
#  'ParsingEgelge.ipynb',
#  'ParsingEPL.ipynb',
#  'ParsingKierge.ipynb',
#  'ParsingMiuz.ipynb',
#  'ParsingNKObyAita.ipynb',
#  'ParsingRNIMU.ipynb',
#  'ParsingSUNLIGHT.ipynb',
#  'pars_16-06-2022_muiz_RSE.xlsx',
#  'README.md',
#  'requiremnts.txt',
#  'results',
#  'resultslinks4154_2410522.xlsx',
#  'rusprice',
#  'tasklogs',
#  'temp10.xlsx',
#  'Untitled.ipynb',
#  'Untitled1-Copy1.ipynb',
#  'Untitled1.ipynb',
#  'visio_matplotlib.ipynb',
#  '__pycache__',
#  'Новая папка',
#  'Разница в стомости изделия Красноярск Москва МЮЗ.docx']

# %%
[a for a in os.scandir()]
# Out:
# [<DirEntry '.DS_Store'>,
#  <DirEntry '.git'>,
#  <DirEntry '.idea'>,
#  <DirEntry '.ipynb_checkpoints'>,
#  <DirEntry 'AnaliticRep031221.ipynb'>,
#  <DirEntry 'AnaliticRep060622EPL_Кольца_с_брилл-62.ipynb'>,
#  <DirEntry 'AnaliticRep061221-KDM1C8.ipynb'>,
#  <DirEntry 'AnaliticRep140422MUIZ_Кольца_с_брилл.ipynb'>,
#  <DirEntry 'AnaliticRep220422EGELGE_брилл.ipynb'>,
#  <DirEntry 'AnaliticRep240522MUIZ_Кольца_с_брилл.ipynb'>,
#  <DirEntry 'collectxls_reps.ipynb'>,
#  <DirEntry 'data.xlsx'>,
#  <DirEntry 'Egelge_1after_parsing.ipynb'>,
#  <DirEntry 'env'>,
#  <DirEntry 'for_parsing_func.ipynb'>,
#  <DirEntry 'jewels'>,
#  <DirEntry 'links'>,
#  <DirEntry 'modules'>,
#  <DirEntry 'MUIZ_justcode.ipynb'>,
#  <DirEntry 'Parsing.html'>,
#  <DirEntry 'ParsingEgelge.ipynb'>,
#  <DirEntry 'ParsingEPL.ipynb'>,
#  <DirEntry 'ParsingKierge.ipynb'>,
#  <DirEntry 'ParsingMiuz.ipynb'>,
#  <DirEntry 'ParsingNKObyAita.ipynb'>,
#  <DirEntry 'ParsingRNIMU.ipynb'>,
#  <DirEntry 'ParsingSUNLIGHT.ipynb'>,
#  <DirEntry 'pars_16-06-2022_muiz_RSE.xlsx'>,
#  <DirEntry 'README.md'>,
#  <DirEntry 'requiremnts.txt'>,
#  <DirEntry 'results'>,
#  <DirEntry 'resultslinks4154_2410522.xlsx'>,
#  <DirEntry 'rusprice'>,
#  <DirEntry 'tasklogs'>,
#  <DirEntry 'temp10.xlsx'>,
#  <DirEntry 'Untitled.ipynb'>,
#  <DirEntry 'Untitled1-Copy1.ipynb'>,
#  <DirEntry 'Untitled1.ipynb'>,
#  <DirEntry 'visio_matplotlib.ipynb'>,
#  <DirEntry '__pycache__'>,
#  <DirEntry 'Новая папка'>,
#  <DirEntry 'Разница в стомости изделия Красноярск Москва МЮЗ.docx'>]

# %% [markdown]
# # Разработка класса Site

# %% [markdown]
# ## Тесты модуля разработки

# %%
dtask = {'name':'SL_diamonds',
         'domain': 'https://sunlight.net/',
         #'links':[],
         'urls0':'https://sunlight.net/catalog/diamonds-all.html',
         'urlslast':'https://sunlight.net/catalog/diamonds-all/page-4/',
         'descr':''}

# %%
dtask = {'name':'alrosa_35_',
         'domain': '',
         #'links':[],
         'urls0':'',
         'urlslast':'',
         'descr':'пустой словарь'}

# %%
task = Dtask(dtask)
# Out:
# установка : alrosa_35_2022-09-22-12-26

# %%
#task = Dtask({'name':'SL_all_1251'})
# Out:
# установка : SL_all_12512022-09-09-16-44

# %%
task.load('d_ALROSA_diamonds_test-352022-09-22-11-59_2022-09-22-12-00.json','name')

# %%
task.print()
# Out:
# task name: alrosa_35_2022-09-22-12-26
# links len =  816
#
# {'name': 'ALROSA_diamonds_test-352022-09-22-11-59',
# 'domain': 'https://sunlight.net/',
# 'urls0': 'https://alrosadiamond.ru/diamonds/',
# 'urlslast': 'https://alrosadiamond.ru/diamonds/pagen_35/',
# 'descr': 'боевой 35 стр по 60',
# 'datestr0': '2022-09-22-11-59',
# 'datestr': '2022-09-22-12-00',
# }

# %%
task.dict['links']
# Out:
# ['/diamonds/22084380/',
#  '/diamonds/22072730/',
#  '/diamonds/21097440/',
#  '/diamonds/22007488/',
#  '/diamonds/22054481/',
#  '/diamonds/11131886/',
#  '/diamonds/15084488/',
#  '/diamonds/15028853/',
#  '/diamonds/15027380/',
#  '/diamonds/15021771/',
#  '/diamonds/15022784/',
#  '/diamonds/15033313/',
#  '/diamonds/16029955/',
#  '/diamonds/12170661/',
#  '/diamonds/16061263/',
#  '/diamonds/17028758/',
#  '/diamonds/19019585/',
#  '/diamonds/18077209/',
#  '/diamonds/18071807/',
#  '/diamonds/18068508/',
#  '/diamonds/18076405/',
#  '/diamonds/20118250/',
#  '/diamonds/19031096/',
#  '/diamonds/18036141/',
#  '/diamonds/20002499/',
#  '/diamonds/20054447/',
#  '/diamonds/18049635/',
#  '/diamonds/18076108/',
#  '/diamonds/15111795/',
#  '/diamonds/15111801/',
#  '/diamonds/19039579/',
#  '/diamonds/19039713/',
#  '/diamonds/14122148/',
#  '/diamonds/20045538/',
#  '/diamonds/20045750/',
#  '/diamonds/20046128/',
#  '/diamonds/20047312/',
#  '/diamonds/20047402/',
#  '/diamonds/20047799/',
#  '/diamonds/20047801/',
#  '/diamonds/20048105/',
#  '/diamonds/20048112/',
#  '/diamonds/20048281/',
#  '/diamonds/20048330/',
#  '/diamonds/20048360/',
#  '/diamonds/20048376/',
#  '/diamonds/20048545/',
#  '/diamonds/20049232/',
#  '/diamonds/21273038/',
#  '/diamonds/21273057/',
#  '/diamonds/21273058/',
#  '/diamonds/21273075/',
#  '/diamonds/21273076/',
#  '/diamonds/21273077/',
#  '/diamonds/21273078/',
#  '/diamonds/21273113/',
#  '/diamonds/21273118/',
#  '/diamonds/21273119/',
#  '/diamonds/21274604/',
#  '/diamonds/21274635/',
#  '/diamonds/21274636/',
#  '/diamonds/21274669/',
#  '/diamonds/21274672/',
#  '/diamonds/21276284/',
#  '/diamonds/21277549/',
#  '/diamonds/21300410/',
#  '/diamonds/21302222/',
#  '/diamonds/22004431/',
#  '/diamonds/22004436/',
#  '/diamonds/22006227/',
#  '/diamonds/22007489/',
#  '/diamonds/22009259/',
#  '/diamonds/22012475/',
#  '/diamonds/22014651/',
#  '/diamonds/21271778/',
#  '/diamonds/21274720/',
#  '/diamonds/21145389/',
#  '/diamonds/21189866/',
#  '/diamonds/21257642/',
#  '/diamonds/22054480/',
#  '/diamonds/22054488/',
#  '/diamonds/22055683/',
#  '/diamonds/22055941/',
#  '/diamonds/22057109/',
#  '/diamonds/22059833/',
#  '/diamonds/22059835/',
#  '/diamonds/22072633/',
#  '/diamonds/22084447/',
#  '/diamonds/22086192/',
#  '/diamonds/22120258/',
#  '/diamonds/22120259/',
#  '/diamonds/22071743/',
#  '/diamonds/22072095/',
#  '/diamonds/22072096/']

# %%
#task.save()
# Out:
# не правильный словарь
# dict записан:  d_SL_diamonds2022-09-07-08-24_2022-09-07-08-25.json

# %%
#task.load()

# %%
#Алроса

# %%
'''v220922
'''
import datetime
import json
import os
import re
import requests
from requests import Request, Session
from bs4 import BeautifulSoup
import pandas as pd


class Site():
    '''v0003 for sunlite '''
    folderres = 'results/'
    
    def __init__(self):
        '''parametr: '''
        #self.dict = dct
        print ('create')#self.dict['domain'])
     
    def mysoup(self,urls):
        response = requests.get(urls)
        return BeautifulSoup(response.text, 'lxml')  
  
    def getlinks_sunl(self,urls):
        quotes = self.mysoup(urls).find_all('a', class_="cl-item-link js-cl-item-link js-cl-item-root-link")
        res = [q.get("href") for q in quotes]
        print(len(res), 'links is ready ' , res[0], '...', res[-1])
        return res
        
        
    def genlinks_sunl(self, task):
        '''task: classes_parsing.Dtask'''
        yield task.dict['urls0']
       # 'urlslast':'https://sunlight.net/catalog/diamonds-all/page-104/'
        text = task.dict['urlslast'].strip().split('/')[-2]
        n = int(re.search(r'\d+',text)[0])
        ch = text[re.search(r'\d+',text).span()[0]-1]
        urls = '/'.join(task.dict['urlslast'].strip().split('/')[0:-2])
        for i in range(2,n):
            pages = f'/page{ch}{i}/'
            #pages = f'&page={i}'#без вставки
            yield urls+pages
                  
        
    def getlinks(self, task)->None:#
        '''create list links and modify object task'''
        genlink = self.genlinks_sunl(task)
        links = []
        i = 0
        for l in genlink:
            print(i, l)
            links += self.getlinks_sunl(l)
            i+=1
        task.dict['links'] = links
        


    def parcing(self, task, linknum0=None, linknum=None):
        def savereserve_csv(data):
            datestr = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
            filename = self.folderres + '/_reserve_' + task.dict['name'] + datestr + '.csv'
            data.to_csv(filename)
            return filename

        data = pd.DataFrame(columns=['h1', 'art', 'price', 'price2', 'gold', 'gold2', 'weight', 'gems', 'gems2', 'url'])
        domain = task.dict['domain']
        links = task.dict['links']
        print('парсинг  total ', len(links))
        num0 = 0 if linknum0==None else linknum0
        num = len(links) if linknum==None else linknum
        print(num0,'--->', num)
        for i in range(num0, num):
            try:
                row = i
                urlcard = domain + links[i]
                response = requests.get(urlcard)
                card = BeautifulSoup(response.text, 'lxml')
                # card = mysoup(urlcard)
                data.loc[row, 'url'] = urlcard
                data.loc[row, 'h1'] = card.find("h1").text.strip()
                data.loc[row, 'art'] = card.find('div',
                                                 class_="supreme-product-card__product-article-text").text.strip()
                data.loc[row, 'price'] = card.find('div',
                                                   class_="supreme-product-card__price-discount-price").text.strip().replace(
                    '\u202f', '').replace('\xa0', '')
                data.loc[row, 'price2'] = card.find('div',
                                                    class_="supreme-product-card__price-old").text.strip().replace(
                    '\u202f', '').replace('\xa0', '')
                a = card.find_all('p',
                                  class_="supreme-product-card__description supreme-product-card__description_default")
                data.loc[row, 'gold'] = ';'.join([x.text for x in a])
                data.loc[row, 'd1'] = "&".join(
                    [t.text for t in card.find_all('span', class_="supreme-product-card-description__item-text")])
                data.loc[row, 'd0'] = "&".join(
                    [t.text for t in card.find_all('a', class_="supreme-product-card-description__item-text")])
                # print(i, urlcard)
            except (AttributeError, TypeError) as e:
                print('error', e)
            except IndexError:
                print('IndexError')
            except Exception as e:
                print('ошибка:', e)
                input('жду')
            print(i, urlcard)
            if i % 100 == 0:
                print('saved', i, savereserve_csv(data))

        lastfile = savereserve_csv(data)
        print('saved last', i, lastfile)
        task.dict['datestr'] = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M')
        task.dict['parcing'] = lastfile
        return data

class Site_alrosa(Site):
    def getlinks_alrosa(self, urls):
        quotes = self.mysoup(urls).find_all('a', class_="product-card__dia21__image-container")
        res = [q.get("href") for q in quotes]
        print(len(res), 'links is ready ', res[0], '...', res[-1])
        return res

    def genlinks_alrosa(self, task):
        '''task: classes_parsing.Dtask'''
        yield task.dict['urls0']
        # 'urlslast':'https://sunlight.net/catalog/diamonds-all/page-104/'
        text = task.dict['urlslast'].strip().split('/')[-2]
        n = int(re.search(r'\d+', text)[0])
        ch = text[re.search(r'\d+', text).span()[0] - 1]
        urls = '/'.join(task.dict['urlslast'].strip().split('/')[0:-2])
        for i in range(2, n):
            pages = f'/pagen{ch}{i}/'
            # pages = f'&page={i}'#без вставки
            yield urls + pages

    def getlinks(self, task) -> None:  #
        '''create list links and modify object task'''
        genlink = self.genlinks_alrosa(task)
        links = []
        i = 0
        for l in genlink:
            print(i, l)
            links += self.getlinks_alrosa(l)
            i += 1
        task.dict['links'] = links

# %%
site = Site_alrosa()
# Out:
# create

# %%
#site.getlinks(task)

# %%
task.print()
# Out:
# task name: SL_diamonds2022-09-07-17-29
# links len =  120
#
# {'name': 'SL_diamonds2022-09-07-17-29',
# 'domain': 'https://sunlight.net/',
# 'urls0': 'https://sunlight.net/catalog/diamonds-all.html',
# 'urlslast': 'https://sunlight.net/catalog/diamonds-all/page-3/',
# 'descr': '',
# 'datestr0': '2022-09-07-17-29',
# 'datestr': None,
# }

# %%
site.parcing(task)
# Out:
# парсинг  total  816
# 0 ---> 816
# error 'NoneType' object has no attribute 'text'
# 0 https://sunlight.net//diamonds/22084380/
# saved 0 results//_reserve_ALROSA_diamonds_test-352022-09-22-11-592022-09-22-12-50.csv
# error 'NoneType' object has no attribute 'text'
# 1 https://sunlight.net//diamonds/22072730/
# error 'NoneType' object has no attribute 'text'
# 2 https://sunlight.net//diamonds/21097440/
# error 'NoneType' object has no attribute 'text'
# 3 https://sunlight.net//diamonds/22007488/
# error 'NoneType' object has no attribute 'text'
# 4 https://sunlight.net//diamonds/22054481/
# error 'NoneType' object has no attribute 'text'
# 5 https://sunlight.net//diamonds/11131886/
# error 'NoneType' object has no attribute 'text'
# 6 https://sunlight.net//diamonds/15084488/
# error 'NoneType' object has no attribute 'text'
# 7 https://sunlight.net//diamonds/15028853/
# error 'NoneType' object has no attribute 'text'
# 8 https://sunlight.net//diamonds/15027380/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3a5ab16dabb1> in <module>
# ----> 1 site.parcing(task)
#
# <ipython-input-10-83477061ea01> in parcing(self, task, linknum0, linknum)
#      76                 row = i
#      77                 urlcard = domain + links[i]
# ---> 78                 response = requests.get(urlcard)
#      79                 card = BeautifulSoup(response.text, 'lxml')
#      80                 # card = mysoup(urlcard)
#
# C:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# C:\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# C:\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# C:\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# C:\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# C:\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# C:\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# C:\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
task.print()
# Out:
# task name: SL_diamonds2022-09-07-17-29
# links len =  120
#
# {'name': 'SL_diamonds2022-09-07-17-29',
# 'domain': 'https://sunlight.net/',
# 'urls0': 'https://sunlight.net/catalog/diamonds-all.html',
# 'urlslast': 'https://sunlight.net/catalog/diamonds-all/page-3/',
# 'descr': '',
# 'datestr0': '2022-09-07-17-29',
# 'datestr': '2022-09-07-17-34',
# 'parcing': 'results//_reserve_SL_diamonds2022-09-07-17-292022-09-07-17-34.csv',
# }

# %%
#task.dict['parcing']='results//_reserve_SL_diamonds2022-09-07-08-07.csv'

# %%
task.save()
# Out:
# не правильный словарь
# dict записан:  d_SL_diamonds2022-09-07-17-29_2022-09-07-17-34.json

# %%
t=Dtask({})
# Out:
# установка : name2022-09-07-12-52

# %%
t.load()
# Out:
# [(0, 'd_SL_diamonds2022-09-06-22-58_2022-09-06-23-02.json'), (1, 'd_SL_diamonds2022-09-07-06-31_2022-09-07-06-34.json'), (2, 'd_SL_diamonds2022-09-07-08-24_2022-09-07-08-25.json'), (3, 'd_SL_diamonds2022-09-07-12-41_2022-09-07-12-51.json'), (4, 'd_SL_diamonds_2022-09-07-08-07.json')]
# введите номер файла: 3
# dict загружен :tasklogs/d_SL_diamonds2022-09-07-12-41_2022-09-07-12-51.json,
#  всего
#  загружены атрибуты dict_keys(['name', 'domain', 'urls0', 'urlslast', 'descr', 'datestr0', 'datestr', 'links', 'parcing'])
# надо определить имя, из какого атрибута взять?
#         [(0, 'name'), (1, 'domain'), (2, 'urls0'), (3, 'urlslast'), (4, 'descr'), (5, 'datestr0'), (6, 'datestr'), (7, 'links'), (8, 'parcing')]
# номер: 0
# выбрано - SL_diamonds2022-09-07-12-41

# %%
t.print()
# Out:
# task name: SL_diamonds2022-09-07-12-41
# links len =  120
#
# {'name': 'SL_diamonds2022-09-07-12-41',
# 'domain': 'https://sunlight.net/',
# 'urls0': 'https://sunlight.net/catalog/diamonds-all.html',
# 'urlslast': 'https://sunlight.net/catalog/diamonds-all/page-3/',
# 'descr': '',
# 'datestr0': '2022-09-07-12-41',
# 'datestr': '2022-09-07-12-51',
# 'parcing': 'results//_reserve_SL_diamonds2022-09-07-12-412022-09-07-12-51.csv',
# }

# %% [markdown]
# ## Добываем линки на карточки SUNLIGHT

# %%
#taskname = 'SL_всеЮИ'
#taskdescr = '579 стр с фильтром https://sunlight.net/catalog/?material=326,327,328,329,3603,632&product_type=317,319,365,366,373,4,414,478,493,494,5,541,745,8,890'
#urls = 'https://sunlight.net/catalog/?material=326,327,328,329,3603,632&product_type=317,319,365,366,373,4,414,478,493,494,5,541,745,8,890'
#domain = f'https://sunlight.net'

# %%
#links = []

# %%
links += getlinks_sunl(urls)
for i in range(512,598):
    #pages = f'page-{i}/'#все 
    pages = f'&page={i}'#без вставки

    print(i, urls+pages)
    links += getlinks_sunl(urls+pages)

# %%
len(links)

# %%
links = list(set(links))

# %%
d2 = Dlinks()

# %%
d2.__doc__

# %%
taskname,  urls, domain, taskdescr

# %%
d2.save(taskname, links, urls, domain, taskdescr)

# %%
links = []

# %%
#def main():

#urls = f'https://sunlight.net/catalog/'#все

urls = f"https://sunlight.net/catalog/?stone=1" #без вставки
domain = f'https://sunlight.net'
links += getlinks_sunl(urls)
for i in range(2,148):
    #pages = f'page-{i}/'#все 
    pages = f'&page={i}'#без вставки

    print(i, urls+pages)
    links += getlinks_sunl(urls+pages)

# %%
len(links)

# %%
#drop duplicates subset keep
links = list(set(links))

# %%
domain+links[0]

# %% [markdown]
# ## Разработка парсера по карточкам

# %%
#urls = 'https://sunlight.net/catalog/page-3/'

# %%
mysoup(urls)

# %%
#def getlinks(urls):
quotes = mysoup(urls).find_all('a', class_="cl-item-link js-cl-item-link js-cl-item-root-link")

# %%
len(quotes)

# %%
quotes[1].get("href")

# %%
res = [q.get("href") for q in quotes]
#    print(len(res), 'links is ready ' , res[0], '...', res[-1])
#    return res

# %%
res

# %%
<a href="/catalog/pendants_90939.html" class="cl-item-link js-cl-item-link js-cl-item-root-link" itemprop="url">
                    <span itemprop="name">Подвеска, вставка: фианит; наносапфир; Серебро 925 пробы.</span>
                </a>

# %%
<a href="/catalog/ring_47781.html" class="cl-item-link js-cl-item-link js-cl-item-root-link" itemprop="url">
                    <span itemprop="name">Кольцо, вставка: фианит; Серебро 925 пробы.</span>
                </a>

# %% [markdown]
# ## Собранная функция парсера по карточкам

# %% [markdown]
# ### Версия 29-08-2022 SUNLIGHT

# %%
data = pd.DataFrame(columns=['h1','art','price','price2','gold','gold2','weight','gems','gems2','url'])

# %%
#data = pd.DataFrame(columns=['h1','art','price','price2','gold','gold2','weight','gems','gems2','url'])

# %%
#29-08-2022 for sunlight 6000
#25-08-2022 all
#06-07-2022 серебро
#16-06-2022 Для Алексея Сапфир Изумруд Рубин
#24-05-2022
#14-04-2022

for i in range(len(links)):
    try:
        row = len(data)
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.find('div', class_="supreme-product-card__product-article-text").text.strip()
        data.loc[row,'price'] = card.find('div', class_="supreme-product-card__price-discount-price").text.strip().replace('\u202f', '').replace('\xa0', '')
        data.loc[row,'price2'] = card.find('div', class_="supreme-product-card__price-old").text.strip().replace('\u202f', '').replace('\xa0', '')
        a = card.find_all('p', class_="supreme-product-card__description supreme-product-card__description_default")
        data.loc[row,'gold'] = ';'.join([x.text for x in a])
        data.loc[row,'d1'] = "&".join([t.text for t in card.find_all('span', class_="supreme-product-card-description__item-text")])
        data.loc[row,'d0'] = "&".join([t.text for t in card.find_all('a', class_="supreme-product-card-description__item-text")])
        #print(i, urlcard)
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
### Поиск ошибки
for i in range(4216, 4217):
    try:
        row = len(data)
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.find('div', class_="supreme-product-card__product-article-text").text.strip()
        data.loc[row,'price'] = card.find('div', class_="supreme-product-card__price-discount-price").text.strip().replace('\u202f', '').replace('\xa0', '')
        data.loc[row,'price2'] = card.find('div', class_="supreme-product-card__price-old").text.strip().replace('\u202f', '').replace('\xa0', '')
        a = card.find_all('p', class_="supreme-product-card__description supreme-product-card__description_default")
        data.loc[row,'gold'] = ';'.join([x.text for x in a])
        data.loc[row,'d1'] = "&".join([t.text for t in card.find_all('span', class_="supreme-product-card-description__item-text")])
        data.loc[row,'d0'] = "&".join([t.text for t in card.find_all('a', class_="supreme-product-card-description__item-text")])
        #print(i, urlcard)
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
len(data)

# %%
data

# %%
domain+links[0]

# %%
urlcard = domain +links[100]
card = mysoup(urlcard)

# %%
#collect 29-08-22
row = len(data)
data.loc[row,'url'] = urlcard
data.loc[row,'h1'] = card.find("h1").text.strip()
data.loc[row,'art'] = card.find('div', class_="supreme-product-card__product-article-text").text.strip()
data.loc[row,'price'] = card.find('div', class_="supreme-product-card__price-discount-price").text.strip().replace('\u202f', '').replace('\xa0', '')
data.loc[row,'price2'] = card.find('div', class_="supreme-product-card__price-old").text.strip().replace('\u202f', '').replace('\xa0', '')
a = card.find_all('p', class_="supreme-product-card__description supreme-product-card__description_default")
data.loc[row,'gold'] = ';'.join([x.text for x in a])
data.loc[row,'d1'] = "&".join([t.text for t in card.find_all('span', class_="supreme-product-card-description__item-text")])
data.loc[row,'d0'] = "&".join([t.text for t in card.find_all('a', class_="supreme-product-card-description__item-text")])

# %%
data

# %%
data.gold.loc[10]

# %%
data = pd.concat([data,data3000_8000], ignore_index=True)

# %%
#res

    data['diam'] = data.gold.apply(lambda x: gold(x, pattern_diam))

    data['goldsilv'] = data.h1.apply(lambda x: gold(x, pattern_gold))

    data['probe'] = data.gold.apply(lambda x: gold(x, pattern_probe))

    data['gramm'] = data.gold.apply(lambda x: gold(x, pattern_gramm))

    data['vst'] = data.gold.apply(lambda x: gold(x, pattern_vst))

    data['type'] = data.gold.apply(lambda x: gold(x, pattern_type))

# %%
#разработка

# %%
<div class="supreme-product-card-description__item-title">
    Бренд
  </div>

# %%
card.find_all('span', class_="supreme-product-card-description__item-text")[4].text

# %%
<a href="https://sunlight.net/catalog/sergey-gribnyakov.html" class="supreme-product-card-description__item-text">SERGEY GRIBNYAKOV</a>

# %%
card.find_all('a', class_="supreme-product-card-description__item-text")

# %%
<div class="supreme-product-card__product-article-text">
      Артикул: 165495
    </div>

# %%
card.find('div', class_="supreme-product-card__product-article-text").text.strip()

# %%
<div class="supreme-product-card__price-discount-price">
  5 395&nbsp;₽
</div>

# %%
card.find('div', class_="supreme-product-card__price-old").text.strip().replace('\u202f', '').replace('\xa0', '')

# %%
card.find('div', class_="supreme-product-card__price-discount-price")

# %%
<div class="supreme-product-card__price-old">
  26 975&nbsp;₽
</div>

# %%
<p class="supreme-product-card__description supreme-product-card__description_default">Кольцо «Бриллианты Якутии» с 21 бриллиантом, огранка круг 17 граней, 0.04 карат, цвет 2, чистота 2, тип огранки Б; 
Розовое золото 585 пробы</p>

# %%
a = card.find_all('p', class_="supreme-product-card__description supreme-product-card__description_default")

# %%
a = card.find_all('p', class_="supreme-product-card__description supreme-product-card__description_default")
';'.join([x.text for x in a])

# %% [markdown]
# ## Визуализация

# %%
 urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select(
            'body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')[0].text
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find(
            "div","places-cont__price b-price").find("div", 'new').text)))
        
        data.loc[row,'price2'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = card.find_all('span','href')[2].text.strip()
        data.loc[row,'gold2'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems2'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]

# %%
card.find_all('span','href')[2].text.strip()

# %%
div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
#data.loc[row,'gems'] = 
re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)

# %%
#25-08-2022 all
#06-07-2022 серебро
#16-06-2022 Для Алексея Сапфир Изумруд Рубин
#24-05-2022
#14-04-2022

for i in range(len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select(
            'body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')[0].text
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find(
            "div","places-cont__price b-price").find("div", 'new').text)))
        
        data.loc[row,'price2'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = card.find_all('span','href')[2].text.strip()
        data.loc[row,'gold2'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems2'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
        
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
data

# %%
data.to_excel('pars_16-06-2022_muiz_RSE.xlsx')

# %% [markdown]
# ### Версия 14-04-2022

# %%
data = pd.DataFrame(columns=['h1','art','price','gold','weight','gems','url'])

# %%
#16-06-2022 Для Алексея Сапфир Изумруд Рубин
#24-05-2022
#14-04-2022

for i in range(len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select(
            'body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')[0].text
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find(
            "div","places-cont__price b-price").find("div", 'new').text)))
        
        #data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %% [markdown]
# ## save res

# %%
import os

# %%
folders = os.listdir()
[q for q in (enumerate(folders))]

# %%
resfolder = folders[26]

# %%
resfolder

# %%
data.to_excel(resfolder+'/'+'sunlight_test01092022.xlsx')

# %%
files = os.listdir('results/')
[f for f in enumerate(files)]

# %%
data = pd.read_csv('results/'+files[9])

# %%
data.loc[1200,'h1']= 1111

# %%
data

# %%
#06-07-2022 серебро
#16-06-2022 Для Алексея Сапфир Изумруд Рубин
#24-05-2022
#14-04-2022

for i in range(0,5):# len(links)):
    try:
        urlcard = domain +links[i]
        card = mysoup(urlcard)
        row = len(data)
        data.loc[row,'url'] = urlcard
        data.loc[row,'h1'] = card.find("h1").text.strip()
        data.loc[row,'art'] = card.select(
            'body > div.grid > div > div > div.shops__breadcrumbs.catalog_breadcrumbs > div > div:nth-child(4) > span > span')[0].text
        data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find(
            "div","places-cont__price b-price").find("div", 'new').text)))
        
        #data.loc[row,'price'] = float(''.join(re.findall(r'\d+', card.find('div',"detail__item-price-new").text)))
        data.loc[row,'gold'] = card.find_all('span','href')[2].text.strip()
        #data.loc[row,'gold'] = re.findall(r"(Золото\s+\d+)",str(card))[0]
        data.loc[row,'weight'] = float(re.findall(r"(?:Вес:</span>\n)\s+(\d+.\d+)",str(card))[0])
        #div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        #data.loc[row,'gems'] = re.search(r'Камни:\s+([\w\W]+)', str(div_gems[0].text.strip()))[1]
        div_gems = card.select('body > div.grid > div > div > div.detail__item.detail__item--new > div.detail__item-col._3.position-relative > form > div:nth-child(8)')
        data.loc[row,'gems'] = re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)
        
    except (AttributeError,TypeError) as e:
        print('error',e)
    except IndexError:
        print('indexerror len of = ' , len(card.find_all('div','detail__item-option')) )
    print(i, urlcard)

# %%
import os

# %%
def fold(sourcepath):
    folders = os.listdir(sourcepath)
    print(*[nf for nf in enumerate(folders)] )
    case = input (sourcepath)
    if case.isdigit():
        sourcepath += folders[int(case)]+"/"
        sourcepath = fold(sourcepath)
        return sourcepath
    else: 
        print(sourcepath)
        return sourcepath

# %%
def source():
    
    p0 = input('path UR-JVV/Users/DAS/Desktop/GM TMP/A Переоценка/ y or enter')
    sourcepath = fold(r'//UR-JVV/Users/DAS/Desktop/GM TMP/A Переоценка/' if p0 == 'y' else p0)
    #'for_site2-1922-1.xlsx'
    files =os.listdir(sourcepath)
    
    filename = files[int(input([n for n in enumerate(files)]))]
    print('filename',filename)
    if not input("y?")=='y':
        print('aborded')
        return False
    #df, file_in = load_df(sourcepath+filename)
    print('test columns in ', (sourcepath+filename))
    return sourcepath, filename
#E:/OM2022/PEREOZENKA/ГИИС

# %%
sourcepath, filename = source()

# %%
sourcepath, filename

# %%
df = pd.read_csv(sourcepath+filename)#.drop(columns='Unnamed: 0')

# %%
df

# %% [markdown]
# ## Загрузка обработка

# %%
task.dict['parcing']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-fb730cab9a2e> in <module>
# ----> 1 task.dict['parcing']
#
# KeyError: 'parcing'

# %%
data = pd.read_csv(task.dict['parcing'])

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
df = pd.read_excel('results/mius_серебро790_06072022.xlsx').drop(columns='Unnamed: 0')

# %%
df.columns

# %%
df.dropna(subset=['weight'], inplace = True)

# %%
#t = 'Серьги c фианитами E2029-1210015246-Z'
#t = 'Кольцо c фианитами R4150-S-LR19653'
t2 = 'Кольцо c жемчугом, сапфирами и фианитами R4150-S-LRP34769S'
t = 'Кольцо fdfd'

# %%
patt_h1_0 = r'([\w\W]+)(?= [A-Z]\d)+?'

# %%
 r'([\w\W]+)(?= [A-Z]\d)+?'

# %%
re.search(patt_h1_0, t2)[1].strip()

# %%
re.search( r'([\w\W]+)', t)[1].strip()

# %%
df['h1_0'] = df.h1.apply(lambda x: re.search(patt, x)[1] if re.search(patt, x) else x)

# %%
patt = patt_h1_0
for n,x in enumerate(df.h1):
    print(n, x,' -- ', (lambda x: re.search(patt, x)[1] if re.search(patt, x) else x)(x))#.strip())

# %%
str(patt_h1_0)

# %%
df.loc[:]

# %%
df['gemsstr'] = df['gems'].str.replace('\[|\]','').str.strip("'")

df['gemslist'] = df.gemsstr.str.split(';')

# %%
df['gemslist'].map(len).unique()

# %%
df['lengem'] = df['gemslist'].map(len)

# %%
df.loc[df['gemslist'].map(len) <= 2, ['gems','gemslist','lengem']]

# %%
sum(df['gemslist'].map(len) > 2)

# %%
df['gem01'] = df['gemslist'].apply(lambda x: x[0])

# %%
df.columns

# %%
df01 = df.loc[df['gemslist'].map(len) <= 2, ['h1_0','h1','gems', 'price', 'gold', 'weight','gem01', 'url','lengem']]

# %%
df01

# %%
t = '38 Фианитов огранки "Круглая", 0.34 карат'

# %%
dic={}

# %%
re.match(r'\d+',t)[0] 
dic['шт_вст'] = r'\d+'

# %%
dic['карат_вст'] = r'[\d.\d]+(?= карат)'
re.search(dic['карат_вст'],t)[0]

# %%
dic['описание_вст'] = r'(?!\d+).+(?=,)'
re.search(dic['описание_вст'],t)[0]

# %%
for c in dic.items():
    print(c)
    df01[c[0]] = df01.gem01.apply(lambda x: re.search(c[1],x)[0] if re.search(c[1],x) else '')

# %%
for n, x in enumerate(df01.gem01):
    print(n,x,'---> ', re.search(r'[\d.\d]+(?= карат)',x)[0] if re.search(r'[\d.\d]+(?= карат)',x) else '')

# %%
df01

# %%
resfolder

# %%
df01.to_excel(resfolder+'/'+'нефть1сорт_серебро_мюз_604_06-07-2022.xlsx')

# %%
df['IDizd'] = df.index

# %%
df.columns

# %%
df.explode("gemslist")  #[["IDizd","gemslist"]]

# %% [markdown]
# ### Отступление, о том как это превратилось в текст и когда, и как я обратно в лист

# %%
from bs4 import BeautifulSoup
import requests
from requests import Request, Session
import pandas as pd

# %%
import re

# %%
def mysoup(urls):
    response = requests.get(urls)
    return BeautifulSoup(response.text, 'lxml')

# %%
card = mysoup('https://miuz.ru/catalog/rings/R4150-S-LRP34775CP/')

# %%
div_gems = card.select('body > div.grid > div > \
div > div.detail__item.detail__item--new > \
div.detail__item-col._3.position-relative >\
form > div:nth-child(8)')
a = re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)
a, type(a)

# %%
data = pd.DataFrame(columns=['h1','art','price','gold','weight','gems','url'])
data.loc[len(data),'gems'] = a

# %%
data['gems']

# %%
data.loc[0,'gems'], type(data.loc[0,'gems'])

# %%
data.to_excel('data.xlsx', index=None)

# %%
data_e = pd.read_excel('data.xlsx')

# %%
data_e['gems']

# %%
data_e.loc[0,'gems'] , type(df.loc[0,'gems'])

# %%
data_e['gems_list'] = data_e['gems'].str.replace('\[|\]','').str.strip("'").str.split(';')

# %%
pd.options.display.max_colwidth = 200

# %%
data_e[['gems','gems_list']]

# %%
data_e.loc[0,'gems_list'] , type(data_e.loc[0,'gems_list'])

# %%
### Отступление, о том как это превратилось в текст и когда, и как я обратно в лист

from bs4 import BeautifulSoup
import requests
from requests import Request, Session
import pandas as pd

import re

def mysoup(urls):
    response = requests.get(urls)
    return BeautifulSoup(response.text, 'lxml')   

card = mysoup('https://miuz.ru/catalog/rings/R4150-S-LRP34775CP/')

div_gems = card.select('body > div.grid > div > \
div > div.detail__item.detail__item--new > \
div.detail__item-col._3.position-relative >\
form > div:nth-child(8)')
a = re.findall(r'Камни:\s+([\w\W]+)', div_gems[0].text)
a, type(a)

data = pd.DataFrame(columns=['h1','art','price','gold','weight','gems','url'])
data.loc[len(data),'gems'] = a

data['gems']

data.loc[0,'gems'], type(data.loc[0,'gems'])

data.to_excel('data.xlsx', index=None)

data_e = pd.read_excel('data.xlsx')

data_e['gems']

data_e.loc[0,'gems'] , type(data_e.loc[0,'gems'])

data_e['gems_list'] = data_e['gems'].str.replace('\[|\]','').str.strip("'").str.split(';')

pd.options.display.max_colwidth = 200

data_e[['gems','gems_list']]

data_e.loc[0,'gems_list'] , type(data_e.loc[0,'gems_list'])

# %%
df

# %%
df.drop(columns='gemsl', inplace=True)

# %%
s = "one [two] three [1] [2]"
print(re.sub('\[|\]', '', s))

# %% [markdown]
# # NOTE

# %%
#Нужная - перезапуск модулей и классов
import importlib 

import classes_parsing #https://stackoverflow.com/questions/6946376/how-to-reload-a-class-in-python-shell

importlib.reload(classes_parsing)

from classes_parsing import Dlinks

classes_parsing.Dlinks.__doc__

Dlinks.__doc__
